# %%
import config

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id, client_secret=config.client_secret))

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY",market="GB")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2017-06-09T17:34:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#        'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#        'id': '2FXC3k01G6Gw61bmprjgqS',
#        'name': 'Hozier',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0Uv83rRhY5QvHKkQoULRKk'},
#      'href': 'https://api.spotify.com/v1/albums/0Uv83rRhY5QvHKkQoULRKk',
#      'id': '0Uv83rRhY5QvHKkQoULRKk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a9bf5f82e32d33d4503fe7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a9bf5f82e32d33d4503fe7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a9bf5f82e32d33d4503fe7b',
#        'width': 64}],
#      'name': 'Hozier',
#      'release_date': '2014-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0Uv83rRhY5QvHKkQoULRKk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#       'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#       'id': '2FXC3k01G6Gw61bmprjgqS',
#       'name': 'Hozier',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#     'disc_number': 1,
#     'duration_ms': 241688,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'IEACJ1300031'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3dYD57lRAUcMHufyqn9GcI'},
#     'href': 'https://api.spotify.com/v1/tracks/3dYD57lRAUcMHufyqn9GcI',
#     'id': '3dYD57lRAUcMHufyqn9GcI',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7dS5EaCoMnN7DzlpT6aRn2'},
#      'href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
#      'id': '7dS5EaCoMnN7DzlpT6aRn2',
#      'type': 'track',
#      'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2'},
#     'name': 'Take Me To Church',
#     'popularity': 85,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3dYD57lRAUcMHufyqn9GcI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-06-29T20:42:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#        'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#        'id': '2KsP6tYLJlTBvSUxnwlVWa',
#        'name': 'Mike Posner',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2nnIlWcriIqcJtjduWcTRl'},
#      'href': 'https://api.spotify.com/v1/albums/2nnIlWcriIqcJtjduWcTRl',
#      'id': '2nnIlWcriIqcJtjduWcTRl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a98ac59b1f31230990d941a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a98ac59b1f31230990d941a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a98ac59b1f31230990d941a2',
#        'width': 64}],
#      'name': '31 Minutes to Takeoff',
#      'release_date': '2010-08-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2nnIlWcriIqcJtjduWcTRl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#       'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#       'id': '2KsP6tYLJlTBvSUxnwlVWa',
#       'name': 'Mike Posner',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Bo8Afb2Qbjs4x6kJHyjle'},
#       'href': 'https://api.spotify.com/v1/artists/1Bo8Afb2Qbjs4x6kJHyjle',
#       'id': '1Bo8Afb2Qbjs4x6kJHyjle',
#       'name': 'Gigamesh',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Bo8Afb2Qbjs4x6kJHyjle'}],
#     'disc_number': 1,
#     'duration_ms': 213293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJAY1000035'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2V4bv1fNWfTcyRJKmej6Sj'},
#     'href': 'https://api.spotify.com/v1/tracks/2V4bv1fNWfTcyRJKmej6Sj',
#     'id': '2V4bv1fNWfTcyRJKmej6Sj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cooler Than Me - Single Mix',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2bdd0657065db57b71f6c34179bde0b45bfbfc89?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-07-19T15:34:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#        'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#        'id': '4V8LLVI7PbaPR0K2TGSxFF',
#        'name': 'Tyler, The Creator',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#      'href': 'https://api.spotify.com/v1/albums/2nkto6YNI4rUYTLqEwWJ3o',
#      'id': '2nkto6YNI4rUYTLqEwWJ3o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738940ac99f49e44f59e6f7fb3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028940ac99f49e44f59e6f7fb3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518940ac99f49e44f59e6f7fb3',
#        'width': 64}],
#      'name': 'Flower Boy',
#      'release_date': '2017-07-21',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2nkto6YNI4rUYTLqEwWJ3o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#       'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#       'id': '4V8LLVI7PbaPR0K2TGSxFF',
#       'name': 'Tyler, The Creator',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#       'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#       'id': '1U1el3k54VvEUzo3ybLPlM',
#       'name': 'Kali Uchis',
#       'type': 'artist',
#       'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#     'disc_number': 1,
#     'duration_ms': 180386,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQX91701275'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB'},
#     'href': 'https://api.spotify.com/v1/tracks/7KA4W4McWYRpgf0fWsJZWB',
#     'id': '7KA4W4McWYRpgf0fWsJZWB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'See You Again (feat. Kali Uchis)',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e9e8d9fce04ab59c61ed9708d9bee03910d5e205?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7KA4W4McWYRpgf0fWsJZWB'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:32:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EQ0qTo7fWT7DPxmxtSYEc'},
#        'href': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc',
#        'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#        'name': 'Bastille',
#        'type': 'artist',
#        'uri': 'spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5G6oMu9zNW2acdV0lqzI3L'},
#      'href': 'https://api.spotify.com/v1/albums/5G6oMu9zNW2acdV0lqzI3L',
#      'id': '5G6oMu9zNW2acdV0lqzI3L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273faee7306ec2f36aeccc4bc98',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02faee7306ec2f36aeccc4bc98',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851faee7306ec2f36aeccc4bc98',
#        'width': 64}],
#      'name': 'All This Bad Blood',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:5G6oMu9zNW2acdV0lqzI3L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EQ0qTo7fWT7DPxmxtSYEc'},
#       'href': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc',
#       'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#       'name': 'Bastille',
#       'type': 'artist',
#       'uri': 'spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc'}],
#     'disc_number': 1,
#     'duration_ms': 214147,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA1200795'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Ub8UsjWuewQrPhuepfVpd'},
#     'href': 'https://api.spotify.com/v1/tracks/4Ub8UsjWuewQrPhuepfVpd',
#     'id': '4Ub8UsjWuewQrPhuepfVpd',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3gbBpTdY8lnQwqxNCcf795'},
#      'href': 'https://api.spotify.com/v1/tracks/3gbBpTdY8lnQwqxNCcf795',
#      'id': '3gbBpTdY8lnQwqxNCcf795',
#      'type': 'track',
#      'uri': 'spotify:track:3gbBpTdY8lnQwqxNCcf795'},
#     'name': 'Pompeii',
#     'popularity': 77,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4Ub8UsjWuewQrPhuepfVpd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#        'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#        'id': '0EmeFodog0BfCgMzAIvKQp',
#        'name': 'Shakira',
#        'type': 'artist',
#        'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ppnlEoj4HdRRdRihnY3jU'},
#      'href': 'https://api.spotify.com/v1/albums/5ppnlEoj4HdRRdRihnY3jU',
#      'id': '5ppnlEoj4HdRRdRihnY3jU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27327ddd747545c0d0cfe7595fa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0227ddd747545c0d0cfe7595fa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485127ddd747545c0d0cfe7595fa',
#        'width': 64}],
#      'name': 'Oral Fixation, Vol. 2 (Expanded Edition)',
#      'release_date': '2005-11-28',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5ppnlEoj4HdRRdRihnY3jU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aBzpmFXB4WWpPl2F7RjBe'},
#       'href': 'https://api.spotify.com/v1/artists/7aBzpmFXB4WWpPl2F7RjBe',
#       'id': '7aBzpmFXB4WWpPl2F7RjBe',
#       'name': 'Wyclef Jean',
#       'type': 'artist',
#       'uri': 'spotify:artist:7aBzpmFXB4WWpPl2F7RjBe'}],
#     'disc_number': 1,
#     'duration_ms': 218093,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10600677'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZFTkvIE7kyPt6Nu3PEa7V'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZFTkvIE7kyPt6Nu3PEa7V',
#     'id': '3ZFTkvIE7kyPt6Nu3PEa7V',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Hips Don't Lie (feat. Wyclef Jean)",
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9743b7c0f0f21da20168327a5c3ceb7f81a1df29?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:31:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#        'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#        'id': '3AQRLZ9PuTAozP28Skbq8V',
#        'name': 'The Script',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JOCOjZTcLysDMkZGWlcIj'},
#      'href': 'https://api.spotify.com/v1/albums/7JOCOjZTcLysDMkZGWlcIj',
#      'id': '7JOCOjZTcLysDMkZGWlcIj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e3049fef96abebf336b7366',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e3049fef96abebf336b7366',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e3049fef96abebf336b7366',
#        'width': 64}],
#      'name': '#3 Deluxe Version',
#      'release_date': '2012-09-10',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7JOCOjZTcLysDMkZGWlcIj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/085pc2PYOi8bGKj0PNjekA'},
#       'href': 'https://api.spotify.com/v1/artists/085pc2PYOi8bGKj0PNjekA',
#       'id': '085pc2PYOi8bGKj0PNjekA',
#       'name': 'will.i.am',
#       'type': 'artist',
#       'uri': 'spotify:artist:085pc2PYOi8bGKj0PNjekA'}],
#     'disc_number': 1,
#     'duration_ms': 202533,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL1201055'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7wMq5n8mYSKlQIGECKUgTX'},
#     'href': 'https://api.spotify.com/v1/tracks/7wMq5n8mYSKlQIGECKUgTX',
#     'id': '7wMq5n8mYSKlQIGECKUgTX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hall of Fame (feat. will.i.am)',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f77afaea9d4b72360f8de353b2b7a361b15e8d2d?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7wMq5n8mYSKlQIGECKUgTX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:31:59Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fahUm8t5c0GIdeTq0ZaG8'},
#        'href': 'https://api.spotify.com/v1/artists/5fahUm8t5c0GIdeTq0ZaG8',
#        'id': '5fahUm8t5c0GIdeTq0ZaG8',
#        'name': 'Otto Knows',
#        'type': 'artist',
#        'uri': 'spotify:artist:5fahUm8t5c0GIdeTq0ZaG8'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6c4fND91gsKojyp3Mox97y'},
#      'href': 'https://api.spotify.com/v1/albums/6c4fND91gsKojyp3Mox97y',
#      'id': '6c4fND91gsKojyp3Mox97y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e86879dff1cf1476698d05c7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e86879dff1cf1476698d05c7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e86879dff1cf1476698d05c7',
#        'width': 64}],
#      'name': 'Back Where I Belong (feat. Avicii)',
#      'release_date': '2016-06-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6c4fND91gsKojyp3Mox97y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fahUm8t5c0GIdeTq0ZaG8'},
#       'href': 'https://api.spotify.com/v1/artists/5fahUm8t5c0GIdeTq0ZaG8',
#       'id': '5fahUm8t5c0GIdeTq0ZaG8',
#       'name': 'Otto Knows',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fahUm8t5c0GIdeTq0ZaG8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#       'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#       'id': '1vCWHaC5f2uS3yhpwWbIA6',
#       'name': 'Avicii',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#     'disc_number': 1,
#     'duration_ms': 174202,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE4OX1600112'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78W8wiUIlQ2SnWY9TVowKZ'},
#     'href': 'https://api.spotify.com/v1/tracks/78W8wiUIlQ2SnWY9TVowKZ',
#     'id': '78W8wiUIlQ2SnWY9TVowKZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back Where I Belong (feat. Avicii)',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/70f13ed60f85e8d9c5fb7635e269c07c35a14bd3?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:78W8wiUIlQ2SnWY9TVowKZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:33:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#        'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#        'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#        'name': 'Selena Gomez',
#        'type': 'artist',
#        'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#        'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#        'id': '6dJeKm76NjfXBNTpHmOhfO',
#        'name': 'Selena Gomez & The Scene',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3sWE3cTMtP9Cvl3aHusvyD'},
#      'href': 'https://api.spotify.com/v1/albums/3sWE3cTMtP9Cvl3aHusvyD',
#      'id': '3sWE3cTMtP9Cvl3aHusvyD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733ff382cef352fba812abd8c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023ff382cef352fba812abd8c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513ff382cef352fba812abd8c1',
#        'width': 64}],
#      'name': 'Love You Like A Love Song, Come & Get It, and More',
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:3sWE3cTMtP9Cvl3aHusvyD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#       'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#       'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#       'name': 'Selena Gomez',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#     'disc_number': 1,
#     'duration_ms': 227373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR11435979'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4n8jPTf8wgI99ryFmbnDPc'},
#     'href': 'https://api.spotify.com/v1/tracks/4n8jPTf8wgI99ryFmbnDPc',
#     'id': '4n8jPTf8wgI99ryFmbnDPc',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2jcPoPin36hyNRSi4ZsqeB'},
#      'href': 'https://api.spotify.com/v1/tracks/2jcPoPin36hyNRSi4ZsqeB',
#      'id': '2jcPoPin36hyNRSi4ZsqeB',
#      'type': 'track',
#      'uri': 'spotify:track:2jcPoPin36hyNRSi4ZsqeB'},
#     'name': 'The Heart Wants What It Wants',
#     'popularity': 67,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4n8jPTf8wgI99ryFmbnDPc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#        'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#        'id': '6MF9fzBmfXghAz953czmBC',
#        'name': 'Taio Cruz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0eGvq1J5Ke7VlLLOYIlY4k'},
#      'href': 'https://api.spotify.com/v1/albums/0eGvq1J5Ke7VlLLOYIlY4k',
#      'id': '0eGvq1J5Ke7VlLLOYIlY4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366c3eb32692a0ae487079cf1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266c3eb32692a0ae487079cf1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166c3eb32692a0ae487079cf1',
#        'width': 64}],
#      'name': 'The Rokstarr Hits Collection',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:0eGvq1J5Ke7VlLLOYIlY4k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#       'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#       'id': '6MF9fzBmfXghAz953czmBC',
#       'name': 'Taio Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#     'disc_number': 1,
#     'duration_ms': 202613,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71003721'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2CEgGE6aESpnmtfiZwYlbV'},
#     'href': 'https://api.spotify.com/v1/tracks/2CEgGE6aESpnmtfiZwYlbV',
#     'id': '2CEgGE6aESpnmtfiZwYlbV',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Dynamite',
#     'popularity': 83,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2CEgGE6aESpnmtfiZwYlbV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#        'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#        'id': '37GUqxafAvAKGMZbXCUnmr',
#        'name': 'Mohombi',
#        'type': 'artist',
#        'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0TFxOkFYPrhIzzrKv5CWZf'},
#      'href': 'https://api.spotify.com/v1/albums/0TFxOkFYPrhIzzrKv5CWZf',
#      'id': '0TFxOkFYPrhIzzrKv5CWZf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733cfcf82ef4d0685f4e4e95a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023cfcf82ef4d0685f4e4e95a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513cfcf82ef4d0685f4e4e95a5',
#        'width': 64}],
#      'name': 'MoveMeant (International)',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0TFxOkFYPrhIzzrKv5CWZf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#       'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#       'id': '37GUqxafAvAKGMZbXCUnmr',
#       'name': 'Mohombi',
#       'type': 'artist',
#       'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#     'disc_number': 1,
#     'duration_ms': 224720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71024652'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71R6zJsrF3ffc3TBFHfivX'},
#     'href': 'https://api.spotify.com/v1/tracks/71R6zJsrF3ffc3TBFHfivX',
#     'id': '71R6zJsrF3ffc3TBFHfivX',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0tBRo4P60DgKmg4jt48upm'},
#      'href': 'https://api.spotify.com/v1/tracks/0tBRo4P60DgKmg4jt48upm',
#      'id': '0tBRo4P60DgKmg4jt48upm',
#      'type': 'track',
#      'uri': 'spotify:track:0tBRo4P60DgKmg4jt48upm'},
#     'name': 'Bumpy Ride',
#     'popularity': 74,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:71R6zJsrF3ffc3TBFHfivX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'},
#        'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E',
#        'id': '5bv5RplEOwdCvhq0EILh9E',
#        'name': 'Lucenzo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1eoYupgvxWRBT6nHnAHjEQ'},
#      'href': 'https://api.spotify.com/v1/albums/1eoYupgvxWRBT6nHnAHjEQ',
#      'id': '1eoYupgvxWRBT6nHnAHjEQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dd6b19d30e8b2531c625fbc4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dd6b19d30e8b2531c625fbc4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dd6b19d30e8b2531c625fbc4',
#        'width': 64}],
#      'name': 'Emigrante Del Mundo (Remastered)',
#      'release_date': '2011-12-19',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1eoYupgvxWRBT6nHnAHjEQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'},
#       'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E',
#       'id': '5bv5RplEOwdCvhq0EILh9E',
#       'name': 'Lucenzo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LqXqd68BBoEk9RDYeS0ls'},
#       'href': 'https://api.spotify.com/v1/artists/4LqXqd68BBoEk9RDYeS0ls',
#       'id': '4LqXqd68BBoEk9RDYeS0ls',
#       'name': 'Big Ali',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LqXqd68BBoEk9RDYeS0ls'}],
#     'disc_number': 1,
#     'duration_ms': 199235,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR43Y1000010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ku3i5WNrsY3qhOq6ua9TL'},
#     'href': 'https://api.spotify.com/v1/tracks/6ku3i5WNrsY3qhOq6ua9TL',
#     'id': '6ku3i5WNrsY3qhOq6ua9TL',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1kAZhbcsXqfUjnVeqPywn2'},
#      'href': 'https://api.spotify.com/v1/tracks/1kAZhbcsXqfUjnVeqPywn2',
#      'id': '1kAZhbcsXqfUjnVeqPywn2',
#      'type': 'track',
#      'uri': 'spotify:track:1kAZhbcsXqfUjnVeqPywn2'},
#     'name': 'Vem Dancar Kuduro',
#     'popularity': 68,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6ku3i5WNrsY3qhOq6ua9TL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZZqIQ25HQmufjjf2trwFO'},
#        'href': 'https://api.spotify.com/v1/artists/5ZZqIQ25HQmufjjf2trwFO',
#        'id': '5ZZqIQ25HQmufjjf2trwFO',
#        'name': 'Cheek',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ZZqIQ25HQmufjjf2trwFO'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Y6qK0mEmyeXHs3DJOGGYO'},
#      'href': 'https://api.spotify.com/v1/albums/3Y6qK0mEmyeXHs3DJOGGYO',
#      'id': '3Y6qK0mEmyeXHs3DJOGGYO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361f43967534f6d07251909ec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261f43967534f6d07251909ec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161f43967534f6d07251909ec',
#        'width': 64}],
#      'name': 'Sokka irti',
#      'release_date': '2012-04-04',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3Y6qK0mEmyeXHs3DJOGGYO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZZqIQ25HQmufjjf2trwFO'},
#       'href': 'https://api.spotify.com/v1/artists/5ZZqIQ25HQmufjjf2trwFO',
#       'id': '5ZZqIQ25HQmufjjf2trwFO',
#       'name': 'Cheek',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZZqIQ25HQmufjjf2trwFO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TZMaBvTPuICA1EQAWjKWZ'},
#       'href': 'https://api.spotify.com/v1/artists/5TZMaBvTPuICA1EQAWjKWZ',
#       'id': '5TZMaBvTPuICA1EQAWjKWZ',
#       'name': 'Yasmine Yamajako',
#       'type': 'artist',
#       'uri': 'spotify:artist:5TZMaBvTPuICA1EQAWjKWZ'}],
#     'disc_number': 1,
#     'duration_ms': 230413,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FIWMA1200063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2N2QvMYwyYHE8V4KZbbG4i'},
#     'href': 'https://api.spotify.com/v1/tracks/2N2QvMYwyYHE8V4KZbbG4i',
#     'id': '2N2QvMYwyYHE8V4KZbbG4i',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Syypää sun hymyyn (feat. Yasmine Yamajako)',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8b23d8aa152c4d57216be77a9a62a5e669aaa621?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2N2QvMYwyYHE8V4KZbbG4i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#        'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#        'id': '0jnsk9HBra6NMjO2oANoPY',
#        'name': 'Flo Rida',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/355RqMyXhDoOD0l4qMUxeT'},
#      'href': 'https://api.spotify.com/v1/albums/355RqMyXhDoOD0l4qMUxeT',
#      'id': '355RqMyXhDoOD0l4qMUxeT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738fff33d4cece7b62bda3a2a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028fff33d4cece7b62bda3a2a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518fff33d4cece7b62bda3a2a5',
#        'width': 64}],
#      'name': 'Whistle',
#      'release_date': '2012-04-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:355RqMyXhDoOD0l4qMUxeT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'disc_number': 1,
#     'duration_ms': 225000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21201745'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ltBH1JNzSvQJPjJpvTu9B'},
#     'href': 'https://api.spotify.com/v1/tracks/0ltBH1JNzSvQJPjJpvTu9B',
#     'id': '0ltBH1JNzSvQJPjJpvTu9B',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Whistle',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/02a8a9e9982c7eb58f153df1a25dcbfe2220b967?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ltBH1JNzSvQJPjJpvTu9B'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#        'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#        'id': '0p4nmQO2msCgU4IF37Wi3j',
#        'name': 'Avril Lavigne',
#        'type': 'artist',
#        'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lqE05fiHWJVYYdMVJNj38'},
#      'href': 'https://api.spotify.com/v1/albums/6lqE05fiHWJVYYdMVJNj38',
#      'id': '6lqE05fiHWJVYYdMVJNj38',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273476cdf5837ae39eee951cc15',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02476cdf5837ae39eee951cc15',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851476cdf5837ae39eee951cc15',
#        'width': 64}],
#      'name': 'The Best Damn Thing (Expanded Edition)',
#      'release_date': '2007-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6lqE05fiHWJVYYdMVJNj38'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#       'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#       'id': '0p4nmQO2msCgU4IF37Wi3j',
#       'name': 'Avril Lavigne',
#       'type': 'artist',
#       'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#     'disc_number': 1,
#     'duration_ms': 216600,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC10700021'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/45hOioMDJktr86iKDHC8gr'},
#     'href': 'https://api.spotify.com/v1/tracks/45hOioMDJktr86iKDHC8gr',
#     'id': '45hOioMDJktr86iKDHC8gr',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HbCnVLXRyZVxnreOPgJCK'},
#      'href': 'https://api.spotify.com/v1/tracks/5HbCnVLXRyZVxnreOPgJCK',
#      'id': '5HbCnVLXRyZVxnreOPgJCK',
#      'type': 'track',
#      'uri': 'spotify:track:5HbCnVLXRyZVxnreOPgJCK'},
#     'name': 'Girlfriend',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/180193873467a5b2e3b83c7be6f56694fb48d80c?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:45hOioMDJktr86iKDHC8gr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3BmcYMh0KYsimWL6p2gPa9'},
#      'href': 'https://api.spotify.com/v1/albums/3BmcYMh0KYsimWL6p2gPa9',
#      'id': '3BmcYMh0KYsimWL6p2gPa9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273629dc9e2e3bc20bbd7d92e4a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02629dc9e2e3bc20bbd7d92e4a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851629dc9e2e3bc20bbd7d92e4a',
#        'width': 64}],
#      'name': 'My World 2.0',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3BmcYMh0KYsimWL6p2gPa9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ipn9JLAPI5GUEo4y4jcoi'},
#       'href': 'https://api.spotify.com/v1/artists/3ipn9JLAPI5GUEo4y4jcoi',
#       'id': '3ipn9JLAPI5GUEo4y4jcoi',
#       'name': 'Ludacris',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ipn9JLAPI5GUEo4y4jcoi'}],
#     'disc_number': 1,
#     'duration_ms': 214240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70919263'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6epn3r7S14KUqlReYr77hA'},
#     'href': 'https://api.spotify.com/v1/tracks/6epn3r7S14KUqlReYr77hA',
#     'id': '6epn3r7S14KUqlReYr77hA',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4NFhtFE68cXUrfbne8JE2c'},
#      'href': 'https://api.spotify.com/v1/tracks/4NFhtFE68cXUrfbne8JE2c',
#      'id': '4NFhtFE68cXUrfbne8JE2c',
#      'type': 'track',
#      'uri': 'spotify:track:4NFhtFE68cXUrfbne8JE2c'},
#     'name': 'Baby',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6epn3r7S14KUqlReYr77hA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#        'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#        'id': '0jnsk9HBra6NMjO2oANoPY',
#        'name': 'Flo Rida',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0aGzTOetC7VdotwXeWLenJ'},
#      'href': 'https://api.spotify.com/v1/albums/0aGzTOetC7VdotwXeWLenJ',
#      'id': '0aGzTOetC7VdotwXeWLenJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea73afbe3f6fe4afb15fccdc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea73afbe3f6fe4afb15fccdc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea73afbe3f6fe4afb15fccdc',
#        'width': 64}],
#      'name': 'Wild Ones (Deluxe)',
#      'release_date': '2012-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0aGzTOetC7VdotwXeWLenJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'disc_number': 1,
#     'duration_ms': 223800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21202584'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5HE3z4Ew7wZ91l3ZOpGKa4'},
#     'href': 'https://api.spotify.com/v1/tracks/5HE3z4Ew7wZ91l3ZOpGKa4',
#     'id': '5HE3z4Ew7wZ91l3ZOpGKa4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Cry',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83ecc26ad34e94df4a61ed9e44cdd3bacda81d6a?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5HE3z4Ew7wZ91l3ZOpGKa4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#        'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#        'id': '37GUqxafAvAKGMZbXCUnmr',
#        'name': 'Mohombi',
#        'type': 'artist',
#        'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0TFxOkFYPrhIzzrKv5CWZf'},
#      'href': 'https://api.spotify.com/v1/albums/0TFxOkFYPrhIzzrKv5CWZf',
#      'id': '0TFxOkFYPrhIzzrKv5CWZf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733cfcf82ef4d0685f4e4e95a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023cfcf82ef4d0685f4e4e95a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513cfcf82ef4d0685f4e4e95a5',
#        'width': 64}],
#      'name': 'MoveMeant (International)',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0TFxOkFYPrhIzzrKv5CWZf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#       'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#       'id': '37GUqxafAvAKGMZbXCUnmr',
#       'name': 'Mohombi',
#       'type': 'artist',
#       'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/40xbWSB4JPdOkRyuTDy1oP'},
#       'href': 'https://api.spotify.com/v1/artists/40xbWSB4JPdOkRyuTDy1oP',
#       'id': '40xbWSB4JPdOkRyuTDy1oP',
#       'name': 'Nicole Scherzinger',
#       'type': 'artist',
#       'uri': 'spotify:artist:40xbWSB4JPdOkRyuTDy1oP'}],
#     'disc_number': 1,
#     'duration_ms': 218373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71027585'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1j7GNdjuK5wfmvxCbVcWMY'},
#     'href': 'https://api.spotify.com/v1/tracks/1j7GNdjuK5wfmvxCbVcWMY',
#     'id': '1j7GNdjuK5wfmvxCbVcWMY',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5L9THbmMKB6ZlHlMgzaXHf'},
#      'href': 'https://api.spotify.com/v1/tracks/5L9THbmMKB6ZlHlMgzaXHf',
#      'id': '5L9THbmMKB6ZlHlMgzaXHf',
#      'type': 'track',
#      'uri': 'spotify:track:5L9THbmMKB6ZlHlMgzaXHf'},
#     'name': 'Coconut Tree',
#     'popularity': 58,
# ...
#      'href': 'https://api.spotify.com/v1/albums/1dgbFU08pXJXZhGPlybdMX',
#      'id': '1dgbFU08pXJXZhGPlybdMX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730bd44f5ff9ecc99f7770acc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020bd44f5ff9ecc99f7770acc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510bd44f5ff9ecc99f7770acc5',
#        'width': 64}],
#      'name': 'THE E.N.D. (THE ENERGY NEVER DIES) [Deluxe Version]',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:1dgbFU08pXJXZhGPlybdMX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 289133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70965169'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4kLLWz7srcuLKA7Et40PQR'},
#     'href': 'https://api.spotify.com/v1/tracks/4kLLWz7srcuLKA7Et40PQR',
#     'id': '4kLLWz7srcuLKA7Et40PQR',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4vp2J1l5RD4gMZwGFLfRAu'},
#      'href': 'https://api.spotify.com/v1/tracks/4vp2J1l5RD4gMZwGFLfRAu',
#      'id': '4vp2J1l5RD4gMZwGFLfRAu',
#      'type': 'track',
#      'uri': 'spotify:track:4vp2J1l5RD4gMZwGFLfRAu'},
#     'name': 'I Gotta Feeling',
#     'popularity': 83,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4kLLWz7srcuLKA7Et40PQR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:38:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ROfBX6lJLnCmaw1NrP5K9'},
#      'href': 'https://api.spotify.com/v1/albums/3ROfBX6lJLnCmaw1NrP5K9',
#      'id': '3ROfBX6lJLnCmaw1NrP5K9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4c5982e1b92f97a126fc18c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4c5982e1b92f97a126fc18c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4c5982e1b92f97a126fc18c',
#        'width': 64}],
#      'name': 'I AM...SASHA FIERCE - Platinum Edition',
#      'release_date': '2008',
#      'release_date_precision': 'year',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3ROfBX6lJLnCmaw1NrP5K9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'disc_number': 1,
#     'duration_ms': 261160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10804556'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2CvOqDpQIMw69cCzWqr5yr'},
#     'href': 'https://api.spotify.com/v1/tracks/2CvOqDpQIMw69cCzWqr5yr',
#     'id': '2CvOqDpQIMw69cCzWqr5yr',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4JehYebiI9JE8sR8MisGVb'},
#      'href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb',
#      'id': '4JehYebiI9JE8sR8MisGVb',
#      'type': 'track',
#      'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb'},
#     'name': 'Halo',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/88b743689e642c02d202e0fc28d18d2a618e4439?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2CvOqDpQIMw69cCzWqr5yr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:38:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#        'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#        'id': '31TPClRtHm23RisEBtV3X7',
#        'name': 'Justin Timberlake',
#        'type': 'artist',
#        'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6QPkyl04rXwTGlGlcYaRoW'},
#      'href': 'https://api.spotify.com/v1/albums/6QPkyl04rXwTGlGlcYaRoW',
#      'id': '6QPkyl04rXwTGlGlcYaRoW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273346a5742374ab4cf9ed32dee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02346a5742374ab4cf9ed32dee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851346a5742374ab4cf9ed32dee',
#        'width': 64}],
#      'name': 'Justified',
#      'release_date': '2002-11-04',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6QPkyl04rXwTGlGlcYaRoW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#       'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#       'id': '31TPClRtHm23RisEBtV3X7',
#       'name': 'Justin Timberlake',
#       'type': 'artist',
#       'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#     'disc_number': 1,
#     'duration_ms': 288333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10200366'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7Lf7oSEVdzZqTA0kEDSlS5'},
#     'href': 'https://api.spotify.com/v1/tracks/7Lf7oSEVdzZqTA0kEDSlS5',
#     'id': '7Lf7oSEVdzZqTA0kEDSlS5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cry Me a River',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/48df99237464a09d5cc4634e2eba8bc846aa1d0a?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7Lf7oSEVdzZqTA0kEDSlS5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:38:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LfGQac0EIXyAN8aUwmNAQ'},
#        'href': 'https://api.spotify.com/v1/artists/5LfGQac0EIXyAN8aUwmNAQ',
#        'id': '5LfGQac0EIXyAN8aUwmNAQ',
#        'name': 'The Offspring',
#        'type': 'artist',
#        'uri': 'spotify:artist:5LfGQac0EIXyAN8aUwmNAQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/67v63ubEsvDUQkYMzI7A9t'},
#      'href': 'https://api.spotify.com/v1/albums/67v63ubEsvDUQkYMzI7A9t',
#      'id': '67v63ubEsvDUQkYMzI7A9t',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273890ce61533a89e00ce593fcb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02890ce61533a89e00ce593fcb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851890ce61533a89e00ce593fcb',
#        'width': 64}],
#      'name': 'Rise And Fall, Rage And Grace',
#      'release_date': '2008-06-17',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:67v63ubEsvDUQkYMzI7A9t'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LfGQac0EIXyAN8aUwmNAQ'},
#       'href': 'https://api.spotify.com/v1/artists/5LfGQac0EIXyAN8aUwmNAQ',
#       'id': '5LfGQac0EIXyAN8aUwmNAQ',
#       'name': 'The Offspring',
#       'type': 'artist',
#       'uri': 'spotify:artist:5LfGQac0EIXyAN8aUwmNAQ'}],
#     'disc_number': 1,
#     'duration_ms': 177826,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM10801605'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6TfBA04WJ3X1d1wXhaCFVT'},
#     'href': 'https://api.spotify.com/v1/tracks/6TfBA04WJ3X1d1wXhaCFVT',
#     'id': '6TfBA04WJ3X1d1wXhaCFVT',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1FMm3wG5WOhi7js35KR7Ea'},
#      'href': 'https://api.spotify.com/v1/tracks/1FMm3wG5WOhi7js35KR7Ea',
#      'id': '1FMm3wG5WOhi7js35KR7Ea',
#      'type': 'track',
#      'uri': 'spotify:track:1FMm3wG5WOhi7js35KR7Ea'},
#     'name': "You're Gonna Go Far, Kid",
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6TfBA04WJ3X1d1wXhaCFVT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KCSPY1glIKqW2TotWuXOR'},
#        'href': 'https://api.spotify.com/v1/artists/1KCSPY1glIKqW2TotWuXOR',
#        'id': '1KCSPY1glIKqW2TotWuXOR',
#        'name': 'P!nk',
#        'type': 'artist',
#        'uri': 'spotify:artist:1KCSPY1glIKqW2TotWuXOR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1LOJfNDxQhbpssKx7oM7at'},
#      'href': 'https://api.spotify.com/v1/albums/1LOJfNDxQhbpssKx7oM7at',
#      'id': '1LOJfNDxQhbpssKx7oM7at',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735a45d5041e4ffcb9f756f740',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025a45d5041e4ffcb9f756f740',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515a45d5041e4ffcb9f756f740',
#        'width': 64}],
#      'name': 'Funhouse (Expanded Edition)',
#      'release_date': '2008-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1LOJfNDxQhbpssKx7oM7at'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KCSPY1glIKqW2TotWuXOR'},
#       'href': 'https://api.spotify.com/v1/artists/1KCSPY1glIKqW2TotWuXOR',
#       'id': '1KCSPY1glIKqW2TotWuXOR',
#       'name': 'P!nk',
#       'type': 'artist',
#       'uri': 'spotify:artist:1KCSPY1glIKqW2TotWuXOR'}],
#     'disc_number': 1,
#     'duration_ms': 215160,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USLF20800067'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0JiY190vktuhSGN6aqJdrt'},
#     'href': 'https://api.spotify.com/v1/tracks/0JiY190vktuhSGN6aqJdrt',
#     'id': '0JiY190vktuhSGN6aqJdrt',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6qYGUxPjQt5PJtWdiNppZx'},
#      'href': 'https://api.spotify.com/v1/tracks/6qYGUxPjQt5PJtWdiNppZx',
#      'id': '6qYGUxPjQt5PJtWdiNppZx',
#      'type': 'track',
#      'uri': 'spotify:track:6qYGUxPjQt5PJtWdiNppZx'},
#     'name': 'So What',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cc38ec35c23165eaf0454a1837a25d08dc40f5de?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0JiY190vktuhSGN6aqJdrt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:31Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#        'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#        'id': '0EmeFodog0BfCgMzAIvKQp',
#        'name': 'Shakira',
#        'type': 'artist',
#        'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4DyMK9x2gnmRkRa16zHaEV'},
#      'href': 'https://api.spotify.com/v1/albums/4DyMK9x2gnmRkRa16zHaEV',
#      'id': '4DyMK9x2gnmRkRa16zHaEV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f400a1f4d821b00824cf58f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f400a1f4d821b00824cf58f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f400a1f4d821b00824cf58f',
#        'width': 64}],
#      'name': 'Laundry Service',
#      'release_date': '2001-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4DyMK9x2gnmRkRa16zHaEV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#     'disc_number': 1,
#     'duration_ms': 196160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLB630100324'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2lnzGkdtDj5mtlcOW2yRtG'},
#     'href': 'https://api.spotify.com/v1/tracks/2lnzGkdtDj5mtlcOW2yRtG',
#     'id': '2lnzGkdtDj5mtlcOW2yRtG',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0RJWhctsc1G1Hg3Ov2th7x'},
#      'href': 'https://api.spotify.com/v1/tracks/0RJWhctsc1G1Hg3Ov2th7x',
#      'id': '0RJWhctsc1G1Hg3Ov2th7x',
#      'type': 'track',
#      'uri': 'spotify:track:0RJWhctsc1G1Hg3Ov2th7x'},
#     'name': 'Whenever, Wherever',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/71832ae5b19c9854ed2241027407be68ae6d7ed8?cid=4099b91e388b4e3890c5525006d72051',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2lnzGkdtDj5mtlcOW2yRtG'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 5295}

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  5295
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
get_playlist_tracks("spotify", "37i9dQZF1DX6cg4h2PoN9y")
# Out:
# [{'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 298899,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105936'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#    'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#    'id': '4RVwu0g32PAqgUiJoXsdF8',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Happier Than Ever',
#    'popularity': 92,
#    'preview_url': None,
#    'track': True,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4iyJ8i3eKbez8JXDbsHIdZ'},
#     'href': 'https://api.spotify.com/v1/albums/4iyJ8i3eKbez8JXDbsHIdZ',
#     'id': '4iyJ8i3eKbez8JXDbsHIdZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e0f2af91be409aad81bba98c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e0f2af91be409aad81bba98c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e0f2af91be409aad81bba98c',
#       'width': 64}],
#     'name': 'Bored',
#     'release_date': '2017-03-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4iyJ8i3eKbez8JXDbsHIdZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 180933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71702756'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/04sN26COy28wTXYj3dMoiZ'},
#    'href': 'https://api.spotify.com/v1/tracks/04sN26COy28wTXYj3dMoiZ',
#    'id': '04sN26COy28wTXYj3dMoiZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bored',
#    'popularity': 87,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:04sN26COy28wTXYj3dMoiZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 244221,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105922'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/42dosBqMOdtgxKw0KRFJF0'},
#    'href': 'https://api.spotify.com/v1/tracks/42dosBqMOdtgxKw0KRFJF0',
#    'id': '42dosBqMOdtgxKw0KRFJF0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Getting Older',
#    'popularity': 68,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:42dosBqMOdtgxKw0KRFJF0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 158463,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105926'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7bcy34fBT2ap1L4bfPsl9q'},
#    'href': 'https://api.spotify.com/v1/tracks/7bcy34fBT2ap1L4bfPsl9q',
#    'id': '7bcy34fBT2ap1L4bfPsl9q',
#    'is_local': False,
#    'is_playable': True,
#    'name': "I Didn't Change My Number",
#    'popularity': 78,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7bcy34fBT2ap1L4bfPsl9q'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 196730,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105927'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2KnuaZYoGzDoHiBTNYOTXG'},
#    'href': 'https://api.spotify.com/v1/tracks/2KnuaZYoGzDoHiBTNYOTXG',
#    'id': '2KnuaZYoGzDoHiBTNYOTXG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Billie Bossa Nova',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2KnuaZYoGzDoHiBTNYOTXG'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 210232,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72104675'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0UJAH9v2PmS7sBcuBquprR'},
#    'href': 'https://api.spotify.com/v1/tracks/0UJAH9v2PmS7sBcuBquprR',
#    'id': '0UJAH9v2PmS7sBcuBquprR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Oxytocin',
#    'popularity': 67,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0UJAH9v2PmS7sBcuBquprR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oxhQpF3Twbkl18oQYfnh5'},
#     'href': 'https://api.spotify.com/v1/albums/3oxhQpF3Twbkl18oQYfnh5',
#     'id': '3oxhQpF3Twbkl18oQYfnh5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273954fe13f7c5f4b2f18d066b8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02954fe13f7c5f4b2f18d066b8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851954fe13f7c5f4b2f18d066b8',
#       'width': 64}],
#     'name': 'my future',
#     'release_date': '2020-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3oxhQpF3Twbkl18oQYfnh5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 208155,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72013019'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ygvZOXrIeVL4xZmAWJT2C'},
#    'href': 'https://api.spotify.com/v1/tracks/2ygvZOXrIeVL4xZmAWJT2C',
#    'id': '2ygvZOXrIeVL4xZmAWJT2C',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'my future',
#    'popularity': 75,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2ygvZOXrIeVL4xZmAWJT2C'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 151536,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105928'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0FfqyjhB6Kspvit1oOo7ax'},
#    'href': 'https://api.spotify.com/v1/tracks/0FfqyjhB6Kspvit1oOo7ax',
#    'id': '0FfqyjhB6Kspvit1oOo7ax',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'GOLDWING',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0FfqyjhB6Kspvit1oOo7ax'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 212496,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72106984'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1LdXpFzKjF7Jz6jA82DYs0'},
#    'href': 'https://api.spotify.com/v1/tracks/1LdXpFzKjF7Jz6jA82DYs0',
#    'id': '1LdXpFzKjF7Jz6jA82DYs0',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3fHNjvF6AU1LXVez0wnFvw'},
#     'href': 'https://api.spotify.com/v1/tracks/3fHNjvF6AU1LXVez0wnFvw',
#     'id': '3fHNjvF6AU1LXVez0wnFvw',
#     'type': 'track',
#     'uri': 'spotify:track:3fHNjvF6AU1LXVez0wnFvw'},
#    'name': 'Lost Cause',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:1LdXpFzKjF7Jz6jA82DYs0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 234761,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105930'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5XsAal7ZcWg1I5T4NcRjkv'},
#    'href': 'https://api.spotify.com/v1/tracks/5XsAal7ZcWg1I5T4NcRjkv',
#    'id': '5XsAal7ZcWg1I5T4NcRjkv',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Halley's Comet",
#    'popularity': 78,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:5XsAal7ZcWg1I5T4NcRjkv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 227679,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105931'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4T2zre0jqstNJ5Gt0WG9lz'},
#    'href': 'https://api.spotify.com/v1/tracks/4T2zre0jqstNJ5Gt0WG9lz',
#    'id': '4T2zre0jqstNJ5Gt0WG9lz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Not My Responsibility',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4T2zre0jqstNJ5Gt0WG9lz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 214058,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105932'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5uSG6fUPRaehaV820zcpsK'},
#    'href': 'https://api.spotify.com/v1/tracks/5uSG6fUPRaehaV820zcpsK',
#    'id': '5uSG6fUPRaehaV820zcpsK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'OverHeated',
#    'popularity': 73,
#    'preview_url': None,
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:5uSG6fUPRaehaV820zcpsK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 206622,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105933'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5jhBwnqzNNrENXnYrAdoCe'},
#    'href': 'https://api.spotify.com/v1/tracks/5jhBwnqzNNrENXnYrAdoCe',
#    'id': '5jhBwnqzNNrENXnYrAdoCe',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Everybody Dies',
#    'popularity': 73,
#    'preview_url': None,
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:5jhBwnqzNNrENXnYrAdoCe'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 245896,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105934'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/042Sl6Mn83JHyLEqdK7uI0'},
#    'href': 'https://api.spotify.com/v1/tracks/042Sl6Mn83JHyLEqdK7uI0',
#    'id': '042Sl6Mn83JHyLEqdK7uI0',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5qNh5WtzMbfpSj2jLlBkoD'},
#     'href': 'https://api.spotify.com/v1/tracks/5qNh5WtzMbfpSj2jLlBkoD',
#     'id': '5qNh5WtzMbfpSj2jLlBkoD',
#     'type': 'track',
#     'uri': 'spotify:track:5qNh5WtzMbfpSj2jLlBkoD'},
#    'name': 'Your Power',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:042Sl6Mn83JHyLEqdK7uI0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 195776,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105935'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/38GBNKZUhfBkk3oNlWzRYd'},
#    'href': 'https://api.spotify.com/v1/tracks/38GBNKZUhfBkk3oNlWzRYd',
#    'id': '38GBNKZUhfBkk3oNlWzRYd',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6uqyE384HDSsuwpoF4mjrL'},
#     'href': 'https://api.spotify.com/v1/tracks/6uqyE384HDSsuwpoF4mjrL',
#     'id': '6uqyE384HDSsuwpoF4mjrL',
#     'type': 'track',
#     'uri': 'spotify:track:6uqyE384HDSsuwpoF4mjrL'},
#    'name': 'NDA',
#    'popularity': 80,
#    'preview_url': None,
#    'track': True,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:38GBNKZUhfBkk3oNlWzRYd'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5G58VVE9ub1KE01Mvbd8XM'},
#     'href': 'https://api.spotify.com/v1/albums/5G58VVE9ub1KE01Mvbd8XM',
#     'id': '5G58VVE9ub1KE01Mvbd8XM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737a152619a7b55bc621d07901',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027a152619a7b55bc621d07901',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517a152619a7b55bc621d07901',
#       'width': 64}],
#     'name': 'Therefore I Am',
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5G58VVE9ub1KE01Mvbd8XM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 174321,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72021500'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/54bFM56PmE4YLRnqpW6Tha'},
#    'href': 'https://api.spotify.com/v1/tracks/54bFM56PmE4YLRnqpW6Tha',
#    'id': '54bFM56PmE4YLRnqpW6Tha',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Therefore I Am',
#    'popularity': 80,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:54bFM56PmE4YLRnqpW6Tha'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 194886,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105937'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/13lUUFsU6GMvRDN432qKxX'},
#    'href': 'https://api.spotify.com/v1/tracks/13lUUFsU6GMvRDN432qKxX',
#    'id': '13lUUFsU6GMvRDN432qKxX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Male Fantasy',
#    'popularity': 63,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:13lUUFsU6GMvRDN432qKxX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4i3rAwPw7Ln2YrKDusaWyT'},
#     'href': 'https://api.spotify.com/v1/albums/4i3rAwPw7Ln2YrKDusaWyT',
#     'id': '4i3rAwPw7Ln2YrKDusaWyT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f2248cf6dad1d6c062587249',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f2248cf6dad1d6c062587249',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f2248cf6dad1d6c062587249',
#       'width': 64}],
#     'name': 'everything i wanted',
#     'release_date': '2019-11-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4i3rAwPw7Ln2YrKDusaWyT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 245425,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71922577'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ZCTVFBt2Brf31RLEnCkWJ'},
#    'href': 'https://api.spotify.com/v1/tracks/3ZCTVFBt2Brf31RLEnCkWJ',
#    'id': '3ZCTVFBt2Brf31RLEnCkWJ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'everything i wanted',
#    'popularity': 84,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3ZCTVFBt2Brf31RLEnCkWJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5sXSHscDjBez8VF20cSyad'},
#     'href': 'https://api.spotify.com/v1/albums/5sXSHscDjBez8VF20cSyad',
#     'id': '5sXSHscDjBez8VF20cSyad',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7b7174bef6f3fbfda3a0bb7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7b7174bef6f3fbfda3a0bb7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7b7174bef6f3fbfda3a0bb7',
#       'width': 64}],
#     'name': 'No Time To Die',
#     'release_date': '2020-02-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5sXSHscDjBez8VF20cSyad'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 242265,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72002771'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73SpzrcaHk0RQPFP73vqVR'},
#    'href': 'https://api.spotify.com/v1/tracks/73SpzrcaHk0RQPFP73vqVR',
#    'id': '73SpzrcaHk0RQPFP73vqVR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'No Time To Die',
#    'popularity': 80,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:73SpzrcaHk0RQPFP73vqVR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#       'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#       'id': '7ltDVBr6mKbRvohxheJ9h1',
#       'name': 'ROSALÍA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4E8puNI8tw7cXz6YJkwMew'},
#     'href': 'https://api.spotify.com/v1/albums/4E8puNI8tw7cXz6YJkwMew',
#     'id': '4E8puNI8tw7cXz6YJkwMew',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c64ed7bab63186d7fca3012f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c64ed7bab63186d7fca3012f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c64ed7bab63186d7fca3012f',
#       'width': 64}],
#     'name': 'Lo Vas A Olvidar (with ROSALÍA)',
#     'release_date': '2021-01-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4E8puNI8tw7cXz6YJkwMew'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#      'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#      'id': '7ltDVBr6mKbRvohxheJ9h1',
#      'name': 'ROSALÍA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#    'disc_number': 1,
#    'duration_ms': 203464,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72100008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0psS4i5YooJrXfDnGvWRLi'},
# ...
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#     'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#     'id': '44OSkEmvHwdTFhPBCewIks',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#       'width': 64}],
#     'name': 'Ocean Eyes (The Remixes)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EpmmPtV7DduqNmeqaADIm'},
#      'href': 'https://api.spotify.com/v1/artists/3EpmmPtV7DduqNmeqaADIm',
#      'id': '3EpmmPtV7DduqNmeqaADIm',
#      'name': 'Astronomyy',
#      'type': 'artist',
#      'uri': 'spotify:artist:3EpmmPtV7DduqNmeqaADIm'}],
#    'disc_number': 1,
#    'duration_ms': 296266,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1611532'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6NOq79ynBpBi6BSJMdgReN'},
#    'href': 'https://api.spotify.com/v1/tracks/6NOq79ynBpBi6BSJMdgReN',
#    'id': '6NOq79ynBpBi6BSJMdgReN',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ocean Eyes - Astronomyy Remix',
#    'popularity': 65,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6NOq79ynBpBi6BSJMdgReN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2I9wpUTuzMT8aS6iVpM2EQ'},
#     'href': 'https://api.spotify.com/v1/albums/2I9wpUTuzMT8aS6iVpM2EQ',
#     'id': '2I9wpUTuzMT8aS6iVpM2EQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b16b427371c5fdd76f1b0ee1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b16b427371c5fdd76f1b0ee1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b16b427371c5fdd76f1b0ee1',
#       'width': 64}],
#     'name': 'Bellyache (Marian Hill Remix)',
#     'release_date': '2017-05-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2I9wpUTuzMT8aS6iVpM2EQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1xHQO9GJIW9OXHxGBISYc5'},
#      'href': 'https://api.spotify.com/v1/artists/1xHQO9GJIW9OXHxGBISYc5',
#      'id': '1xHQO9GJIW9OXHxGBISYc5',
#      'name': 'Marian Hill',
#      'type': 'artist',
#      'uri': 'spotify:artist:1xHQO9GJIW9OXHxGBISYc5'}],
#    'disc_number': 1,
#    'duration_ms': 220800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71703692'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/61X077SWMs5aAGQHhf4pd0'},
#    'href': 'https://api.spotify.com/v1/tracks/61X077SWMs5aAGQHhf4pd0',
#    'id': '61X077SWMs5aAGQHhf4pd0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bellyache - Marian Hill Remix',
#    'popularity': 64,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:61X077SWMs5aAGQHhf4pd0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#     'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#     'id': '44OSkEmvHwdTFhPBCewIks',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#       'width': 64}],
#     'name': 'Ocean Eyes (The Remixes)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#      'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#      'id': '2cFrymmkijnjDg9SS92EPM',
#      'name': 'blackbear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#    'disc_number': 1,
#    'duration_ms': 195306,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1611534'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4JuZQeSRYJfLCqBgBIxxrR'},
#    'href': 'https://api.spotify.com/v1/tracks/4JuZQeSRYJfLCqBgBIxxrR',
#    'id': '4JuZQeSRYJfLCqBgBIxxrR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ocean Eyes - Blackbear Remix',
#    'popularity': 68,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4JuZQeSRYJfLCqBgBIxxrR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#       'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#       'id': '586uxXMyD5ObPuzjtrzO1Q',
#       'name': 'Sofi Tukker',
#       'type': 'artist',
#       'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5XRJoC2QtsNbAubsCrBBbG'},
#     'href': 'https://api.spotify.com/v1/albums/5XRJoC2QtsNbAubsCrBBbG',
#     'id': '5XRJoC2QtsNbAubsCrBBbG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738fbc40da547bc157e8956cea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028fbc40da547bc157e8956cea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518fbc40da547bc157e8956cea',
#       'width': 64}],
#     'name': 'COPYCAT (Sofi Tukker Remix)',
#     'release_date': '2018-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5XRJoC2QtsNbAubsCrBBbG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#      'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#      'id': '586uxXMyD5ObPuzjtrzO1Q',
#      'name': 'Sofi Tukker',
#      'type': 'artist',
#      'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'}],
#    'disc_number': 1,
#    'duration_ms': 198684,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71713025'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2njUxZ4151DWIrfIK3loFj'},
#    'href': 'https://api.spotify.com/v1/tracks/2njUxZ4151DWIrfIK3loFj',
#    'id': '2njUxZ4151DWIrfIK3loFj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'COPYCAT - Sofi Tukker Remix',
#    'popularity': 63,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2njUxZ4151DWIrfIK3loFj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7Chuv69qWaXuK5eCmZ8gCi'},
#     'href': 'https://api.spotify.com/v1/albums/7Chuv69qWaXuK5eCmZ8gCi',
#     'id': '7Chuv69qWaXuK5eCmZ8gCi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737b9881aa297e336c0d4d5cef',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027b9881aa297e336c0d4d5cef',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517b9881aa297e336c0d4d5cef',
#       'width': 64}],
#     'name': 'Six Feet Under (The Remixes)',
#     'release_date': '2017-02-03',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:7Chuv69qWaXuK5eCmZ8gCi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/356FCJoyYWyzONni54Dgrv'},
#      'href': 'https://api.spotify.com/v1/artists/356FCJoyYWyzONni54Dgrv',
#      'id': '356FCJoyYWyzONni54Dgrv',
#      'name': 'Jerry Folk',
#      'type': 'artist',
#      'uri': 'spotify:artist:356FCJoyYWyzONni54Dgrv'}],
#    'disc_number': 1,
#    'duration_ms': 200898,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71700468'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/58nxGpcCfNDiqmFXklOslz'},
#    'href': 'https://api.spotify.com/v1/tracks/58nxGpcCfNDiqmFXklOslz',
#    'id': '58nxGpcCfNDiqmFXklOslz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Six Feet Under - Jerry Folk Remix',
#    'popularity': 61,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:58nxGpcCfNDiqmFXklOslz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#     'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#     'id': '44OSkEmvHwdTFhPBCewIks',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#       'width': 64}],
#     'name': 'Ocean Eyes (The Remixes)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/670UISOh9XV1zlq5z5IfoY'},
#      'href': 'https://api.spotify.com/v1/artists/670UISOh9XV1zlq5z5IfoY',
#      'id': '670UISOh9XV1zlq5z5IfoY',
#      'name': 'GOLDHOUSE',
#      'type': 'artist',
#      'uri': 'spotify:artist:670UISOh9XV1zlq5z5IfoY'}],
#    'disc_number': 1,
#    'duration_ms': 213600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1637941'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1JbuC7uZm0P1PyX7N7gDEM'},
#    'href': 'https://api.spotify.com/v1/tracks/1JbuC7uZm0P1PyX7N7gDEM',
#    'id': '1JbuC7uZm0P1PyX7N7gDEM',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ocean Eyes - GOLDHOUSE Remix',
#    'popularity': 59,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1JbuC7uZm0P1PyX7N7gDEM'},
#   'video_thumbnail': {'url': None}}]

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['',
#  'Estelle',
#  'Shapov',
#  'Marc Anthony',
#  'The Living Tombstone',
#  'David Guetta',
#  'Becky Hill',
#  'Lost Kings',
#  'Treyy G',
#  'Adam Lambert',
#  'Bananarama',
#  'Maiki',
#  'Thundercat',
#  'Duran Duran',
#  'Mk.gee',
#  'Särre',
#  'Skepta',
#  'D.O.E.',
#  'Dua Lipa',
#  'Famous Ocean & KungFu',
#  'Machine Gun Kelly',
#  'Kid Crave',
#  'Brennan Heart',
#  'Masked Wolf',
#  'Josh A',
#  'Dizzee Rascal',
#  'Hendersin',
#  'Sofía Reyes',
#  'Sexmane',
#  'Jessie J',
#  'Sideshow',
#  'Good Charlotte',
#  'Lana Del Rey',
#  'Lewis Capaldi',
#  'Macklemore & Ryan Lewis',
#  'Tears For Fears',
#  'Mikkel Øwre',
#  'Romy Dya',
#  'The Chainsmokers',
#  'MASN',
#  'Bella Thorne',
#  'Gus Dapperton',
#  'Duo',
#  'KSHMR',
#  'Christina Aguilera',
#  'Kurupt',
#  'ILOVEMAKONNEN',
#  'Mariska',
#  'Freddy Kalas',
#  'Michael Marshall',
#  'Kyler England',
#  'Eazy-E',
#  'Carly Rae Jepsen',
#  'Ezkimo',
#  'Matti Salminen',
#  'Oz Sparx',
#  'Bass Modulators',
#  'Laidback Luke',
#  'DJ Snake',
#  'Sallitut Aineet',
#  'L.V.',
#  'VilleGalle',
#  'JAY-Z',
#  'Tommy Trash',
#  'Haiti Babii',
#  'Of Monsters and Men',
#  'Juize',
#  'Wyclef Jean',
#  'Sam Fischer',
#  'benny blanco',
#  'Preme',
#  'Tatarka',
#  'Imanbek',
#  'The Game',
#  'Nicholas Fraser',
#  'Alphaville',
#  'Juliette Claire',
#  'Oh Wonder',
#  'Chivv',
#  'Marja',
#  'Steven A. Clark',
#  'Mac Miller',
#  'Tove Lo',
#  'Rich The Kid',
#  'Kylie Minogue',
#  'CJ',
#  'Mokita',
#  'Fasion',
#  'Samuli Putro',
#  'Alis',
#  'Kelis',
#  'Bill Wurtz',
#  'MEDUZA',
#  'KajO',
#  'Reset',
#  'Leven Kali',
#  'Grace Phipps',
#  'Kash Doll',
#  'Michael Andrews',
#  'Keala Settle',
#  'MD$',
#  'Robin Packalen',
#  'Drenchill',
#  'Michel Teló',
#  'The Vamps',
#  'Foe G4ng',
#  'Ariana Grande',
#  'Classified',
#  'Death Grips',
#  'Ruudolf',
#  'Promoting Sounds',
#  'Corona',
#  'Aloe Blacc',
#  'Fabolous',
#  'Breakbot',
#  'Bastille',
#  'Wintertime',
#  'Tomppabeats',
#  'A.G.',
#  'Hilary Duff',
#  'Arctic Monkeys',
#  'Jon Bellion',
#  'Jason Derulo',
#  'Taylor Swift',
#  'Martin Garrix',
#  'Bazzi',
#  'Ella Henderson',
#  'Ruel',
#  'Chimamanda Ngozi Adichie',
#  'Rick Ross',
#  'Surf Curse',
#  'Death Cab for Cutie',
#  'Rixton',
#  'Daft Punk',
#  'Tarrus Riley',
#  'Wheeler Walker Jr.',
#  'Queen Key',
#  'Big Time Rush',
#  'Versace Henrik',
#  'Black Veil Brides',
#  'Kim Herold',
#  'Guy Sebastian',
#  'Farruko',
#  'Joel Adams',
#  'Backstreet Boys',
#  'SHRTY',
#  'Drake Bell',
#  'Jacob Sartorius',
#  'Ann Marie',
#  'Tez Cadey',
#  'Kristal',
#  'SNBRN',
#  'Kaija Koo',
#  'TLC',
#  'Stryker Pose',
#  'Vance Joy',
#  'Frankie Knuckles',
#  'Rex Orange County',
#  'Chris Jones',
#  'Au/Ra',
#  'Yello',
#  'Keri Hilson',
#  'R.I.O.',
#  'Sia',
#  'Surfaces',
#  'Oliver Francis',
#  'DJ Frank E',
#  'MYKKA',
#  'Dean Martin',
#  'Juice WRLD',
#  'Quando Rondo',
#  'Wallows',
#  'Sofia Carson',
#  'Njomza',
#  'Poo Bear',
#  'Nick "Fierce" Fiorucci',
#  'Donny',
#  'Kendrick Lamar',
#  'Sleeping At Last',
#  'jxdn',
#  'Jessie Reyez',
#  'Are',
#  'Craymer',
#  'The American Idiot Broadway Company',
#  'Tinashe',
#  'Skylar Grey',
#  'Martin Jensen',
#  'Tasis',
#  'The Notorious B.I.G.',
#  'Havana Brown',
#  'Sean Paul of Youngbloodz',
#  'Ralph Tresvant',
#  '6LACK',
#  'Pyrythekid',
#  'Vanessa Carlton',
#  'MC Hammer',
#  'Ryan Tedder',
#  'Lil Wil',
#  'Kevin Gates',
#  'Saara Aalto',
#  'Eve',
#  'Jay Prince',
#  'Hardwell',
#  'Ross Lynch',
#  'Zedd',
#  'Dave Audé for Awestruck Productions, Inc.',
#  'Fintelligens',
#  'The Lonely Island',
#  'Enrique Iglesias',
#  'Eduardo Nascimento',
#  'Mahogany Lox',
#  'Take A Daytrip',
#  'Tyla Yaweh',
#  'Sam Smith',
#  'Internet Money',
#  'K CAMP',
#  'MHD',
#  'XAM',
#  'Evanescence',
#  'The Civil Wars',
#  'KYLE',
#  'J. Cole',
#  'Helena Bonham Carter',
#  'E-40',
#  'Tiny Tim',
#  'Sharon',
#  'Regard',
#  'Kevin Tandu',
#  'DJ Sammy',
#  'Jonne Aaron',
#  'Eric Prydz',
#  'Yanou',
#  'Mandi',
#  'Twista',
#  'Asian Doll',
#  'Toby Fox',
#  'Jeezy',
#  'Cuban Doll',
#  'Gabry Ponte',
#  'Anna of the North',
#  'Kim Petras',
#  'Ella Eyre',
#  'Sista Prod',
#  'Logic',
#  'Coolio',
#  'Cezinando',
#  'La Bouche',
#  'Dr. Dre',
#  'Survivor',
#  'Nicco',
#  'Elton John',
#  'Lil Kapow',
#  'ItaloBrothers',
#  'Elke Diels',
#  'Sani',
#  'Tuure Boelius',
#  'Joel Corry',
#  'Kasmir',
#  'Larray',
#  'Joker Inc',
#  'Zak Abel',
#  'Kah-Lo',
#  'Sophie',
#  'Janieck Devy',
#  'Roscoe Dash',
#  'Vicetone',
#  'Cheat Codes',
#  'Green Day',
#  'Quality Control',
#  'Calboy',
#  'Cody Simpson',
#  'La Cream',
#  'Black Eyed Peas',
#  'Popeda',
#  'Hot Shade',
#  'DJ Sequenza',
#  'Lil Pump',
#  'MØ',
#  'Chief Keef',
#  'Grimes',
#  'Matthew Wilder',
#  'Janelle Monáe',
#  'Mannie Fresh',
#  'Jesse Markin',
#  'WSTRN',
#  'AREA21',
#  'Afro Bros',
#  'Bryce Vine',
#  'Ashley All Day',
#  'Roy Jones Jr.',
#  'dj 6rb',
#  'J.I the Prince of N.Y',
#  'Vinny West',
#  'Rich Brian',
#  'Majuri',
#  'Shawn Hook',
#  'Grouplove',
#  'Central Cee',
#  'Limp Bizkit',
#  'Flying Lotus',
#  'Teuvo Loman',
#  'Mustard',
#  'Thomas Jack',
#  'Alfons',
#  'Indy & Karim',
#  'Mikko Pohjola',
#  'American Authors',
#  'Injury Reserve',
#  'Elena Coats',
#  'Vigiland',
#  'Mariska & Pahat Sudet',
#  'The Cataracs',
#  'Johnny Yukon',
#  'Cigarettes After Sex',
#  'EDEN',
#  'KAMASUTRA 9G',
#  'Sam Martin',
#  'Captain Cuts',
#  'Queen',
#  'Frances Forever',
#  'Craig Xen',
#  'Eevil Stöö',
#  'Mesto',
#  'Nelli Matula',
#  'C & C Music Factory',
#  'Don Huonot',
#  'blackbear',
#  'Tony Arzadon',
#  'Artem x Yonas',
#  'Joji',
#  'Linkin Park',
#  'Matoma',
#  'MKTO',
#  'Wasted Penguinz',
#  'Digital Farm Animals',
#  'Mack 10',
#  'Frostydasnowmann',
#  'Emily Roberts',
#  'Michel Zitron',
#  'Darude',
#  'Jayceeoh',
#  'Katri Helena',
#  'Madchild',
#  'Rick Rock',
#  'Roy Woods',
#  'Cardi B',
#  'Oso Faneto',
#  'SHY Martin',
#  'Jay Cosmic',
#  'Sanjin',
#  'Descemer Bueno',
#  'House Of Pain',
#  'La La La La',
#  'Tommee Profitt',
#  'Bobby Shmurda',
#  'Tegan and Sara',
#  'Ray J',
#  'Alanis Morissette',
#  'D-Block & S-te-Fan',
#  'D.O.D',
#  'Marilii',
#  'Sash!',
#  'Ty Dolla $ign',
#  'Diego Miranda',
#  'Snakehips',
#  'Dirty South',
#  'Radiohead',
#  'Ozuna',
#  'Bryson Tiller',
#  'Iamsu!',
#  'Speernorman',
#  'Will Smith',
#  'M-Fuse',
#  'LOLO',
#  'Mr. 305',
#  'Dragonette',
#  'Cal Chuchesta',
#  'Petri Nygård',
#  'fun.',
#  'Dominic Fike',
#  'Hampton The Hampster',
#  'Tinie Tempah',
#  'Gettomasa',
#  "Auli'i Cravalho",
#  'Jeremy Zucker',
#  'Ege Zulu',
#  'ZAYN',
#  'Measure',
#  'Dj Slim D',
#  'Kamaiyah',
#  'Lyttä',
#  'Musta-Lista',
#  'Reino Nordin',
#  'Maren Morris',
#  'Töölön Ketterä',
#  'Louisa',
#  'DeJ Loaf',
#  'Joznez',
#  'Haneri',
#  'Vory',
#  'Sean Kingston',
#  'Vepu',
#  "I'Dees",
#  'Conrad Sewell',
#  'Aurora',
#  'KC',
#  'Tee Grizzley',
#  'Marc Stout',
#  'Lookas',
#  'Sir Mix-A-Lot',
#  'Swizz Beatz',
#  'Ava Max',
#  'Sander van Doorn',
#  'Nick Bonin',
#  'Tommi Läntinen',
#  'Oliver Nelson',
#  'Anne-Marie',
#  'Sam Feldt',
#  'Tauski',
#  'Tuomas Kauhanen',
#  'Goodboys',
#  'iamjakehill',
#  't.A.T.u.',
#  'Mac DeMarco',
#  'Paleface',
#  'Annabel Jones',
#  'Arrhult',
#  'JP Saxe',
#  'El Cata',
#  'Rik Rok',
#  'Protoculture',
#  'The Band Perry',
#  'TheHxliday',
#  'Pehmee Goo',
#  'Lorde',
#  'Jesse Kaikuranta',
#  'Steve Aoki',
#  'Jake Reese',
#  'TIX',
#  'Kesh Kesh',
#  'SZA',
#  'Tyler, The Creator',
#  'Jussi 69',
#  'Janne Ordén',
#  'DJ Scheme',
#  'Coldplay',
#  'Michelle Williams',
#  'One Direction',
#  'Future',
#  'Chisu',
#  'dvsn',
#  'Little Sis Nora',
#  'Linda',
#  'Mind Vortex',
#  'Molly',
#  'J. Karjalainen Yhtyeineen',
#  'Valovuosi',
#  'Sleepy Tom',
#  'Lil Revive',
#  'Simple Plan',
#  'Mellen Gi',
#  'A Touch Of Class',
#  'Aerosmith',
#  'Big Sean',
#  'Costi',
#  'Dawin',
#  'Fall Out Boy',
#  'Lykke Li',
#  'Waterparks',
#  'Jope Ruonansuu',
#  'Foreigner',
#  'LVNDSCAPE',
#  'DJ Sliink',
#  'Dido',
#  'Wale',
#  'Sasha Lopez',
#  'Black Gryph0n',
#  'Sabrina Carpenter',
#  'Benny Sings',
#  'Supergrass',
#  'Georgi Kay',
#  'Luniz',
#  'P!nk',
#  'CALVO',
#  'Sikdope',
#  'The Ronettes',
#  'JACKBOYS',
#  'Møtions',
#  'LIZ',
#  'Erika Vikman',
#  'Vesala',
#  'Mark McCabe',
#  'Eyedress',
#  'Daniel Caesar',
#  'JVG',
#  'Seeb',
#  'Ilsey',
#  'VASSY',
#  'Jannika B',
#  'Lil Xan',
#  'Jack Harlow',
#  'Timo Pieni Huijaus',
#  'Julma H',
#  'Alok',
#  'Current Joys',
#  'XXXTENTACION',
#  'Unlike Pluto',
#  'Miriam Bryant',
#  'frzndisciple',
#  'WTF!',
#  'Kill The Noise',
#  'Delaney Jane',
#  'DJ White Shadow',
#  'Pouya',
#  'Jack Perry',
#  'Cascada',
#  'MIKA',
#  'Showtek',
#  'YBN Nahmir',
#  'Space Cowboy',
#  'Ressu Redford',
#  '2 Chainz',
#  'Lou Bega',
#  'Zara Larsson',
#  'Disco Ensemble',
#  'Spark Master Tape',
#  'Cavallini',
#  'LP',
#  'Dave Stewart',
#  'Dorrough Music',
#  'Edward Maya',
#  'Laura Voutilainen',
#  'Tuuli',
#  'Yung Bae',
#  'JP Cooper',
#  'Lil Gotit',
#  'AronChupa',
#  'mayklove',
#  'Floorfilla',
#  'The Boyboy West Coast',
#  'Otto Knows',
#  'Vengaboys',
#  'Aki Tykki',
#  'LSD',
#  'Shortster 0161',
#  'Kanye West',
#  'Dreezy',
#  'Jasmine Thompson',
#  'Galantis',
#  'FTampa',
#  '916frosty',
#  'Tay Money',
#  'Mikael Gabriel',
#  'Tohtori Getto',
#  'Chad Kroeger',
#  'Missy Elliott',
#  'The Naked And Famous',
#  'Tiktak',
#  'DJ SpinKing',
#  'DJ KIMERA',
#  'Gotye',
#  'Shakira',
#  'The Flint Chozen Choir',
#  'Ski Mask The Slump God',
#  'Echosmith',
#  'Devault',
#  'MAGIC!',
#  'Pekka Kuusisto',
#  'Black Sabbath',
#  'A Boogie Wit da Hoodie',
#  'Jumal X10 Lavis',
#  'Eric Turner',
#  'Videoclub',
#  'E-Rotic',
#  'Hausmylly',
#  'Roddy Ricch',
#  'THEY.',
#  'Pharrell Williams',
#  'Sturm und Drang',
#  'Rock Mafia',
#  'Redman',
#  'Jack & Jack',
#  'The Prince Karma',
#  'Lil Tjay',
#  'Juulia',
#  'Jhené Aiko',
#  'Sirena',
#  'Bobby Helms',
#  'Bizi',
#  'Bang For The Buck',
#  'Johanna Kurkela',
#  'NF',
#  'Nightcore',
#  'Aamupojat',
#  '*NSYNC',
#  'Kehlani',
#  "Bomfunk MC's",
#  'Mike Williams',
#  'AJ McLean',
#  'Danny Quest',
#  'Marcus Schössow',
#  'Rita Ora',
#  'Ant Saunders',
#  'Bryan Adams',
#  'Amy Diamond',
#  'Seekae',
#  'Chelsea Cutler',
#  'Christina Perri',
#  'Las Ketchup',
#  'Archie Cruz',
#  'Dropgun',
#  'G.R.L.',
#  'Janieck',
#  'Giorgio Tuinfort',
#  'Aly & AJ',
#  'Mark Ronson',
#  'Malmö',
#  'Ruma',
#  'Asap Vergi',
#  'Tones And I',
#  'Monica',
#  'R.E.M.',
#  'Jack Joseph Puig',
#  'Don Toliver',
#  'Lauri Ylönen',
#  'LUCA',
#  'Lexi Jayde',
#  'Axwell /\\ Ingrosso',
#  'Riva Starr',
#  'V.I.C.',
#  'Erin',
#  'Avicii',
#  'Say Lou Lou',
#  'Mike Candys',
#  'RONNIE',
#  'Shania Twain',
#  'Vika Jigulina',
#  'Kid Travis',
#  'Pia Mia',
#  'Kings of Leon',
#  'Running Touch',
#  'Lonely God',
#  'Train',
#  'Brendon Urie',
#  'Tunji Ige',
#  'Rudimental',
#  'Jimilian',
#  'Kraantje Pappie',
#  'U2',
#  'Britt Daley',
#  'Demi Lovato',
#  '$wave',
#  'John Newman',
#  'Ruben Haze',
#  'Hayley Kiyoko',
#  'Isaiah Firebrace',
#  'Gala',
#  'Vesa-Matti Loiri',
#  'JORI SJÖROOS',
#  'Busta Rhymes',
#  'Tacabro',
#  'Disclosure',
#  'Lil Uzi Vert',
#  'Zendaya',
#  'Matte Caliste',
#  'Snow Patrol',
#  'Stepa',
#  'Fools Garden',
#  'Karri Koira',
#  'Flo Rida',
#  'Da Tweekaz',
#  'Big Syke',
#  'Stunna 4 Vegas',
#  'John Legend',
#  'Mindless Self Indulgence',
#  'Taikapeili',
#  'Skandaali',
#  'Fifth Harmony',
#  'Cobra Starship',
#  'Vanessa Hudgens',
#  'Tony Junior',
#  'Zoe Nash',
#  'Yolanda Be Cool',
#  'Taio Cruz',
#  'Harry Belafonte',
#  'Example',
#  'Bloodhound Gang',
#  'Giveon',
#  'The Magician',
#  'Maroon 5',
#  'Tierra Whack',
#  'Heikki Kuula',
#  'Danny Avila',
#  'Gwen Stefani',
#  'Justin Bieber',
#  'John Martin',
#  'Kaoma',
#  'Benji Reyes',
#  '27CLUB',
#  'Temur',
#  'Joe Jonas',
#  'Adi L Hasla',
#  'Fareoh',
#  'Illi',
#  'Abandoning Sunday',
#  'Bruno Mars',
#  'Alyson Stoner',
#  'Terri B!',
#  'Conor Maynard',
#  'Yung Gleesh',
#  'Nicki Minaj',
#  'Mascolo',
#  'Nikke Ankara',
#  'Little Simz',
#  'Trevor Daniel',
#  'Justin Mylo',
#  'Portugal. The Man',
#  'The Goo Goo Dolls',
#  'Style of Eye',
#  'Tame Impala',
#  'Layton Greene',
#  'Ummet Ozcan',
#  'Rune RK',
#  'Christopher Needle',
#  'Sean Paul',
#  'Jeffrey James',
#  'Aika',
#  'French Montana',
#  'Amy Macdonald',
#  'Vesta',
#  'Cordae',
#  'Tre Coast',
#  'Spekti',
#  'Robin',
#  'The Pøssy Project',
#  'Talk Talk',
#  'GraphicMuzik',
#  'King Staccz',
#  'R. Kelly',
#  'Herba',
#  'Shawn Mendes',
#  'Tori Kelly',
#  'Lukas Meijer',
#  'Beardyman',
#  'The Outlaws',
#  'O.C',
#  'Wreck',
#  'LILMozart',
#  'Audien',
#  'Kodaline',
#  'Ramz',
#  'Ethan Fields',
#  'Frank Moody',
#  'Foxes',
#  'Collin McLoughlin',
#  "Ol' Dirty Bastard",
#  'Millie B',
#  'YB026',
#  'Aleesia',
#  'Juno',
#  'Shenie Fogo',
#  'Blind Channel',
#  'HVME',
#  'Live for the weekend',
#  'Prince Royce',
#  'Timeflies',
#  'DJ Blyatman',
#  'Mr. Probz',
#  'Faydee',
#  'Aleksanteri Hakaniemi',
#  'Sharpay Evans',
#  'Florence Welch',
#  'Ice Cube',
#  'Lil Tecca',
#  'Ola',
#  'Hailee Steinfeld',
#  'Shepard',
#  'Vaboh',
#  'Filip Jenven',
#  'Blake Michael',
#  'Savage Ga$p',
#  'Master Blaster',
#  'STIG',
#  'Pusha T',
#  'Yung Gravy',
#  'Noam Kaniel',
#  'Freshlyground',
#  'Lakko',
#  'Loote',
#  'InfaRed',
#  'Strange Talk',
#  'Beach Bunny',
#  '$NOT',
#  'CADE',
#  'Julie Bergan',
#  'Meek Mill',
#  'Anders Nilsen',
#  'Swedish House Mafia',
#  'KSI',
#  'STEREO',
#  'Popcaan',
#  'Mascara',
#  'JoJo',
#  'Boys Noize',
#  'twocolors',
#  'X Ambassadors',
#  'HRVY',
#  'Matias',
#  'Dani Poppitt',
#  'De La Ghetto',
#  'DNCE',
#  'Sigrid',
#  'Vula',
#  'Sage The Gemini',
#  'Jax Jones',
#  'Bryce',
#  'Gromee',
#  'Niko Saarinen',
#  'Siine',
#  'Modern Talking',
#  'Dagny',
#  'Adizi X Typelik',
#  'IDOLS-Finalistit 2007',
#  'kai',
#  'Justimus',
#  'Cher',
#  'Phoebe Ryan',
#  'Spooks',
#  'Nopsajalka',
#  'Michael Bublé',
#  'Getter Jaani',
#  'Evelina',
#  'Third Party',
#  'The Him',
#  'Hussa',
#  'Gracias',
#  'Florida Georgia Line',
#  'Fellatia Geisha',
#  'Becky G',
#  'Young Roc',
#  'Scorpions',
#  'Ronan Keating',
#  'Lauv',
#  'Takeo Ischi',
#  'Spice Girls',
#  'ibe',
#  "Charlie's Angels",
#  'Kris Kross Amsterdam',
#  'Post Malone',
#  'Sami Saari',
#  'Scarlet',
#  'Danelle Sandoval',
#  'Rob $tone',
#  'Devon Baldwin',
#  'Sliki & Hamuelos',
#  'Cassadee Pope',
#  'Ella Mai',
#  'Faith Evans',
#  'Stephen',
#  'iSHi',
#  'Francesco Yates',
#  'Clairo',
#  'Sugarland',
#  'TWENTY88',
#  'Eva Simons',
#  'Pet Shop Boys',
#  'HEDEGAARD',
#  'Daya',
#  'Night Lovell',
#  'ODEE',
#  'Selena Gomez',
#  'Pendulum',
#  'Buddy',
#  'The Script',
#  'Kuwada',
#  'Tony Igy',
#  'Nate Dogg',
#  'Kiiara',
#  'Anssi Kela',
#  'KANDY',
#  'Do',
#  'Matisse & Sadko',
#  'U96',
#  'Captain Jack',
#  'Krewella',
#  'YNW Melly',
#  'G Herbo',
#  'Joey Bada$$',
#  'FLETCHER',
#  'Juicy J',
#  'DJ Fresh',
#  'Lily Allen',
#  'KILLBOY',
#  'Kid Ink',
#  'Bobby Summer',
#  'IKE',
#  'Ellie Goulding',
#  'Jhay Cortez',
#  'LeAnn Rimes',
#  'Rico Nasty',
#  'Loreen',
#  'Alex Joseph',
#  'DaBaby',
#  'Ester Dean',
#  'Sofi Tukker',
#  'Absofacto',
#  'Slim Jxmmi',
#  'Bhad Bhabie',
#  'Ben Morfitt (SquidPhysics)',
#  'Rat City',
#  'Journey',
#  'N.W.A.',
#  'Shotgun Willy',
#  'Lil Mosey',
#  'Alexandra Stan',
#  'Ace of Base',
#  "Waldo's People",
#  'Roxette',
#  'MOGUAI',
#  'Mike Tompkins',
#  'David Rush',
#  'Aqua',
#  'Sasha Alex Sloan',
#  'Katri Ylander',
#  'Janet Jackson',
#  'Lilli Paasikivi',
#  'Portion Boys',
#  'Asa',
#  'Jontte Valosaari',
#  'Leona Lewis',
#  'Brädi',
#  'Mozzy',
#  'Kodak Black',
#  'Kymppilinja',
#  'la haka',
#  'Louis Tomlinson',
#  'Zeeba',
#  'Jenni Vartiainen',
#  'Heretic Klick',
#  'Khlaw',
#  'Antti Railio',
#  'Jess Glynne',
#  'Static Major',
#  'Matthew Koma',
#  'Brooks',
#  'Saweetie',
#  'Shinedown',
#  'Ida Paul',
#  'ABREU',
#  'BROCKHAMPTON',
#  'Murcy',
#  'Luke Combs',
#  'Fernando',
#  'Neea',
#  'Chase Atlantic',
#  'Wheatus',
#  'DROELOE',
#  'POORSTACY',
#  'Quavo',
#  'Dante Leon',
#  'Faul & Wad',
#  'Gabriella',
#  'Drew Love',
#  'Daze',
#  'Madison Love',
#  'We The Kings',
#  'Elley Duhé',
#  'Tate McRae',
#  'Jozo',
#  'FKi 1st',
#  'Mon DJ',
#  'Maxx',
#  'Funk Wav',
#  'Chance the Rapper',
#  'Jedidi',
#  'Emil Assergård',
#  'Henna Narva',
#  'Alexandra Babitzin',
#  'The Mistery',
#  'Egzod',
#  'Era Istrefi',
#  'WALK THE MOON',
#  'Young Thug',
#  'Lit',
#  'VINAI',
#  'Kuningasidea',
#  'Marvin Gaye',
#  'Bonnie Tyler',
#  'James Newton Howard',
#  'KT Tunstall',
#  'Will Sparks',
#  'Hurts',
#  'Matisyahu',
#  'Soulja Boy',
#  'Marshmello',
#  'Savage Garden',
#  'Bonn',
#  'Paradisio',
#  'Michael Bolton',
#  'Jack McManus',
#  ...]

# %%
def get_artists_from_track(track):
    return[artist["name"] for artist in track["artists"]]

#--------------------------------------------------------------------

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
def get_artists_ids_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_ids_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
artists = get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY") # Apply the function
artists_ids = get_artists_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
len(artists)
# Out:
# 2445

# %%
len(artists_ids) # We might have more ids due to artists having the same name
# Out:
# 2448

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %%
get_albums_from_artist("6qqNVTkY8uBg9cP3Jd7DAH")
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#   'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#   'id': '0JGOiO34nwfUdDrD612dOp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#     'width': 64}],
#   'name': 'Happier Than Ever',
#   'release_date': '2021-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#   'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#   'id': '5tzRuO6GP7WRvP3rEOPAO9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#     'width': 64}],
#   'name': 'Happier Than Ever',
#   'release_date': '2021-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#   'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#   'id': '0S0KGZnfBGSIssfF54WSJh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#     'width': 64}],
#   'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'release_date': '2019-03-29',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2kzPJWrTjVKEYWWhowXLnz'},
#   'href': 'https://api.spotify.com/v1/albums/2kzPJWrTjVKEYWWhowXLnz',
#   'id': '2kzPJWrTjVKEYWWhowXLnz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331aa3ebe23f59778bff800c9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231aa3ebe23f59778bff800c9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131aa3ebe23f59778bff800c9',
#     'width': 64}],
#   'name': 'Happier Than Ever (Edit)',
#   'release_date': '2021-07-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2kzPJWrTjVKEYWWhowXLnz'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5lDUpb6zBr4xBh9AGUXYtQ'},
#   'href': 'https://api.spotify.com/v1/albums/5lDUpb6zBr4xBh9AGUXYtQ',
#   'id': '5lDUpb6zBr4xBh9AGUXYtQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735f831fc87adfeab20ce97c7b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025f831fc87adfeab20ce97c7b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515f831fc87adfeab20ce97c7b',
#     'width': 64}],
#   'name': 'Happier Than Ever (Edit)',
#   'release_date': '2021-07-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5lDUpb6zBr4xBh9AGUXYtQ'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2AyexmwyUy1nZfBadyewL7'},
#   'href': 'https://api.spotify.com/v1/albums/2AyexmwyUy1nZfBadyewL7',
#   'id': '2AyexmwyUy1nZfBadyewL7',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27398a3d331aad09aede2a9dcad',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0298a3d331aad09aede2a9dcad',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485198a3d331aad09aede2a9dcad',
#     'width': 64}],
#   'name': 'ilomilo (Live From The Film - Billie Eilish: The World’s A Little Blurry)',
#   'release_date': '2021-02-22',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2AyexmwyUy1nZfBadyewL7'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#     'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#     'id': '7ltDVBr6mKbRvohxheJ9h1',
#     'name': 'ROSALÍA',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4E8puNI8tw7cXz6YJkwMew'},
#   'href': 'https://api.spotify.com/v1/albums/4E8puNI8tw7cXz6YJkwMew',
#   'id': '4E8puNI8tw7cXz6YJkwMew',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c64ed7bab63186d7fca3012f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c64ed7bab63186d7fca3012f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c64ed7bab63186d7fca3012f',
#     'width': 64}],
#   'name': 'Lo Vas A Olvidar (with ROSALÍA)',
#   'release_date': '2021-01-21',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4E8puNI8tw7cXz6YJkwMew'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5G58VVE9ub1KE01Mvbd8XM'},
#   'href': 'https://api.spotify.com/v1/albums/5G58VVE9ub1KE01Mvbd8XM',
#   'id': '5G58VVE9ub1KE01Mvbd8XM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737a152619a7b55bc621d07901',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027a152619a7b55bc621d07901',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517a152619a7b55bc621d07901',
#     'width': 64}],
#   'name': 'Therefore I Am',
#   'release_date': '2020-11-12',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5G58VVE9ub1KE01Mvbd8XM'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3oxhQpF3Twbkl18oQYfnh5'},
#   'href': 'https://api.spotify.com/v1/albums/3oxhQpF3Twbkl18oQYfnh5',
#   'id': '3oxhQpF3Twbkl18oQYfnh5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273954fe13f7c5f4b2f18d066b8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02954fe13f7c5f4b2f18d066b8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851954fe13f7c5f4b2f18d066b8',
#     'width': 64}],
#   'name': 'my future',
#   'release_date': '2020-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3oxhQpF3Twbkl18oQYfnh5'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5sXSHscDjBez8VF20cSyad'},
#   'href': 'https://api.spotify.com/v1/albums/5sXSHscDjBez8VF20cSyad',
#   'id': '5sXSHscDjBez8VF20cSyad',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f7b7174bef6f3fbfda3a0bb7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f7b7174bef6f3fbfda3a0bb7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f7b7174bef6f3fbfda3a0bb7',
#     'width': 64}],
#   'name': 'No Time To Die',
#   'release_date': '2020-02-13',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5sXSHscDjBez8VF20cSyad'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4i3rAwPw7Ln2YrKDusaWyT'},
#   'href': 'https://api.spotify.com/v1/albums/4i3rAwPw7Ln2YrKDusaWyT',
#   'id': '4i3rAwPw7Ln2YrKDusaWyT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f2248cf6dad1d6c062587249',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f2248cf6dad1d6c062587249',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f2248cf6dad1d6c062587249',
#     'width': 64}],
#   'name': 'everything i wanted',
#   'release_date': '2019-11-13',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4i3rAwPw7Ln2YrKDusaWyT'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'name': 'Justin Bieber',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6lMlX68jJrx67hiCqdiDvW'},
#   'href': 'https://api.spotify.com/v1/albums/6lMlX68jJrx67hiCqdiDvW',
#   'id': '6lMlX68jJrx67hiCqdiDvW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a69b8b111a5fb8cb1c97e8eb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a69b8b111a5fb8cb1c97e8eb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a69b8b111a5fb8cb1c97e8eb',
#     'width': 64}],
#   'name': 'bad guy (with Justin Bieber)',
#   'release_date': '2019-07-11',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6lMlX68jJrx67hiCqdiDvW'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0LgnntyagLdfW5Dz2OSYHU'},
#   'href': 'https://api.spotify.com/v1/albums/0LgnntyagLdfW5Dz2OSYHU',
#   'id': '0LgnntyagLdfW5Dz2OSYHU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27373f85e8b4338d2aa07f59f3a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0273f85e8b4338d2aa07f59f3a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485173f85e8b4338d2aa07f59f3a',
#     'width': 64}],
#   'name': 'WHEN I WAS OLDER (Music Inspired By The Film ROMA)',
#   'release_date': '2019-01-09',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0LgnntyagLdfW5Dz2OSYHU'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0ifM8RTX9HjtCJtY9452bW'},
#   'href': 'https://api.spotify.com/v1/albums/0ifM8RTX9HjtCJtY9452bW',
#   'id': '0ifM8RTX9HjtCJtY9452bW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27348a98a5a97b2cc7963016888',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0248a98a5a97b2cc7963016888',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485148a98a5a97b2cc7963016888',
#     'width': 64}],
#   'name': 'come out and play',
#   'release_date': '2018-11-20',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0ifM8RTX9HjtCJtY9452bW'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#     'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#     'id': '6LuN9FCkKOj5PcnpouEgny',
#     'name': 'Khalid',
#     'type': 'artist',
#     'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#   'href': 'https://api.spotify.com/v1/albums/2sBB17RXTamvj7Ncps15AK',
#   'id': '2sBB17RXTamvj7Ncps15AK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738a3f0a3ca7929dea23cd274c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518a3f0a3ca7929dea23cd274c',
#     'width': 64}],
#   'name': 'lovely (with Khalid)',
#   'release_date': '2018-04-19',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2sBB17RXTamvj7Ncps15AK'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Z0XtKcevvITZ5ydimkYcx'},
#   'href': 'https://api.spotify.com/v1/albums/1Z0XtKcevvITZ5ydimkYcx',
#   'id': '1Z0XtKcevvITZ5ydimkYcx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273408b5dbd24ad9f44bb1af72f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02408b5dbd24ad9f44bb1af72f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851408b5dbd24ad9f44bb1af72f',
#     'width': 64}],
#   'name': 'bitches broken hearts',
#   'release_date': '2018-03-30',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:1Z0XtKcevvITZ5ydimkYcx'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5m9lO9SriYMPpXTrVIU8P5'},
#   'href': 'https://api.spotify.com/v1/albums/5m9lO9SriYMPpXTrVIU8P5',
#   'id': '5m9lO9SriYMPpXTrVIU8P5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b01e0794e65a909958897fa2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b01e0794e65a909958897fa2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b01e0794e65a909958897fa2',
#     'width': 64}],
#   'name': 'MyBoi (TroyBoi Remix)',
#   'release_date': '2018-03-09',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5m9lO9SriYMPpXTrVIU8P5'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#     'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#     'id': '586uxXMyD5ObPuzjtrzO1Q',
#     'name': 'Sofi Tukker',
#     'type': 'artist',
#     'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5XRJoC2QtsNbAubsCrBBbG'},
#   'href': 'https://api.spotify.com/v1/albums/5XRJoC2QtsNbAubsCrBBbG',
#   'id': '5XRJoC2QtsNbAubsCrBBbG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738fbc40da547bc157e8956cea',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028fbc40da547bc157e8956cea',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518fbc40da547bc157e8956cea',
#     'width': 64}],
#   'name': 'COPYCAT (Sofi Tukker Remix)',
#   'release_date': '2018-01-12',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5XRJoC2QtsNbAubsCrBBbG'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7fRrTyKvE4Skh93v97gtcU'},
#   'href': 'https://api.spotify.com/v1/albums/7fRrTyKvE4Skh93v97gtcU',
#   'id': '7fRrTyKvE4Skh93v97gtcU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a9f6c04ba168640b48aa5795',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a9f6c04ba168640b48aa5795',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a9f6c04ba168640b48aa5795',
#     'width': 64}],
#   'name': 'dont smile at me',
#   'release_date': '2017-12-22',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:7fRrTyKvE4Skh93v97gtcU'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/68kEuyFKyqrdQQLLsmiatm'},
#     'href': 'https://api.spotify.com/v1/artists/68kEuyFKyqrdQQLLsmiatm',
#     'id': '68kEuyFKyqrdQQLLsmiatm',
#     'name': 'Vince Staples',
#     'type': 'artist',
#     'uri': 'spotify:artist:68kEuyFKyqrdQQLLsmiatm'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6eQpKhYCtvD0TwXQVHsgC2'},
#   'href': 'https://api.spotify.com/v1/albums/6eQpKhYCtvD0TwXQVHsgC2',
#   'id': '6eQpKhYCtvD0TwXQVHsgC2',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f3425d012117543bf914c451',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f3425d012117543bf914c451',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f3425d012117543bf914c451',
#     'width': 64}],
#   'name': '&burn (with Vince Staples)',
#   'release_date': '2017-12-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6eQpKhYCtvD0TwXQVHsgC2'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5YCdlD3eREt72lTZxNL7id'},
#   'href': 'https://api.spotify.com/v1/albums/5YCdlD3eREt72lTZxNL7id',
#   'id': '5YCdlD3eREt72lTZxNL7id',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739c05fec02bd9b81ee1246b2f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029c05fec02bd9b81ee1246b2f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519c05fec02bd9b81ee1246b2f',
#     'width': 64}],
#   'name': 'dont smile at me (Expanded Edition)',
#   'release_date': '2017-08-11',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:5YCdlD3eREt72lTZxNL7id'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2I9wpUTuzMT8aS6iVpM2EQ'},
#   'href': 'https://api.spotify.com/v1/albums/2I9wpUTuzMT8aS6iVpM2EQ',
#   'id': '2I9wpUTuzMT8aS6iVpM2EQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b16b427371c5fdd76f1b0ee1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b16b427371c5fdd76f1b0ee1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b16b427371c5fdd76f1b0ee1',
#     'width': 64}],
#   'name': 'Bellyache (Marian Hill Remix)',
#   'release_date': '2017-05-05',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2I9wpUTuzMT8aS6iVpM2EQ'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4iyJ8i3eKbez8JXDbsHIdZ'},
#   'href': 'https://api.spotify.com/v1/albums/4iyJ8i3eKbez8JXDbsHIdZ',
#   'id': '4iyJ8i3eKbez8JXDbsHIdZ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e0f2af91be409aad81bba98c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e0f2af91be409aad81bba98c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e0f2af91be409aad81bba98c',
#     'width': 64}],
#   'name': 'Bored',
#   'release_date': '2017-03-30',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4iyJ8i3eKbez8JXDbsHIdZ'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/25FGyvj0UnD6YYWLq0s9nl'},
#   'href': 'https://api.spotify.com/v1/albums/25FGyvj0UnD6YYWLq0s9nl',
#   'id': '25FGyvj0UnD6YYWLq0s9nl',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734adbeb26299adca766cec2c5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024adbeb26299adca766cec2c5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514adbeb26299adca766cec2c5',
#     'width': 64}],
#   'name': 'Bellyache',
#   'release_date': '2017-02-24',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:25FGyvj0UnD6YYWLq0s9nl'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7Chuv69qWaXuK5eCmZ8gCi'},
#   'href': 'https://api.spotify.com/v1/albums/7Chuv69qWaXuK5eCmZ8gCi',
#   'id': '7Chuv69qWaXuK5eCmZ8gCi',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737b9881aa297e336c0d4d5cef',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027b9881aa297e336c0d4d5cef',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517b9881aa297e336c0d4d5cef',
#     'width': 64}],
#   'name': 'Six Feet Under (The Remixes)',
#   'release_date': '2017-02-03',
#   'release_date_precision': 'day',
#   'total_tracks': 4,
#   'type': 'album',
#   'uri': 'spotify:album:7Chuv69qWaXuK5eCmZ8gCi'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#   'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#   'id': '44OSkEmvHwdTFhPBCewIks',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#     'width': 64}],
#   'name': 'Ocean Eyes (The Remixes)',
#   'release_date': '2017-01-13',
#   'release_date_precision': 'day',
#   'total_tracks': 4,
#   'type': 'album',
#   'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/74TRp3O8BRdGxc0XO0UzoY'},
#   'href': 'https://api.spotify.com/v1/albums/74TRp3O8BRdGxc0XO0UzoY',
#   'id': '74TRp3O8BRdGxc0XO0UzoY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fae80fc6c7f60e75cfc519c7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fae80fc6c7f60e75cfc519c7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fae80fc6c7f60e75cfc519c7',
#     'width': 64}],
#   'name': 'Six Feet Under',
#   'release_date': '2016-11-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:74TRp3O8BRdGxc0XO0UzoY'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3iMZi6l2502goK32DZW3KM'},
#   'href': 'https://api.spotify.com/v1/albums/3iMZi6l2502goK32DZW3KM',
#   'id': '3iMZi6l2502goK32DZW3KM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732b387540043b47ef37ed56d0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022b387540043b47ef37ed56d0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512b387540043b47ef37ed56d0',
#     'width': 64}],
#   'name': 'Women in Pop 2022',
#   'release_date': '2022-02-16',
#   'release_date_precision': 'day',
#   'total_tracks': 26,
#   'type': 'album',
#   'uri': 'spotify:album:3iMZi6l2502goK32DZW3KM'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0LBFk6SlIrTPD2PA9GtgHB'},
#   'href': 'https://api.spotify.com/v1/albums/0LBFk6SlIrTPD2PA9GtgHB',
#   'id': '0LBFk6SlIrTPD2PA9GtgHB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dad9dd528c6b48a8234cd058',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dad9dd528c6b48a8234cd058',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dad9dd528c6b48a8234cd058',
#     'width': 64}],
#   'name': "daydreamin'",
#   'release_date': '2022-02-15',
#   'release_date_precision': 'day',
#   'total_tracks': 25,
#   'type': 'album',
#   'uri': 'spotify:album:0LBFk6SlIrTPD2PA9GtgHB'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7jlfUhtGWmfNaaNviJJrhh'},
#   'href': 'https://api.spotify.com/v1/albums/7jlfUhtGWmfNaaNviJJrhh',
#   'id': '7jlfUhtGWmfNaaNviJJrhh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d1b3875db272f301febc9925',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d1b3875db272f301febc9925',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d1b3875db272f301febc9925',
#     'width': 64}],
#   'name': 'Music For Kids 2022',
#   'release_date': '2022-02-15',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:7jlfUhtGWmfNaaNviJJrhh'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3N1VI9LguMtIqaS7A6qoLG'},
#   'href': 'https://api.spotify.com/v1/albums/3N1VI9LguMtIqaS7A6qoLG',
#   'id': '3N1VI9LguMtIqaS7A6qoLG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27381f03ba3e491e4e36c386e60',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0281f03ba3e491e4e36c386e60',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485181f03ba3e491e4e36c386e60',
#     'width': 64}],
#   'name': "Best Valentine's Day 2022",
#   'release_date': '2022-02-14',
#   'release_date_precision': 'day',
#   'total_tracks': 26,
#   'type': 'album',
#   'uri': 'spotify:album:3N1VI9LguMtIqaS7A6qoLG'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6v1EhQQESorCwSjRE8cfwx'},
#   'href': 'https://api.spotify.com/v1/albums/6v1EhQQESorCwSjRE8cfwx',
#   'id': '6v1EhQQESorCwSjRE8cfwx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27341c9ce9ecbbba767c2a8eb40',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0241c9ce9ecbbba767c2a8eb40',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485141c9ce9ecbbba767c2a8eb40',
#     'width': 64}],
#   'name': "I Hate Valentine's Day",
#   'release_date': '2022-02-14',
#   'release_date_precision': 'day',
#   'total_tracks': 38,
#   'type': 'album',
#   'uri': 'spotify:album:6v1EhQQESorCwSjRE8cfwx'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6m33bBnWHlGsIr3iyl5vJc'},
#   'href': 'https://api.spotify.com/v1/albums/6m33bBnWHlGsIr3iyl5vJc',
#   'id': '6m33bBnWHlGsIr3iyl5vJc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d6dc84bc490905cb3ba7511d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d6dc84bc490905cb3ba7511d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d6dc84bc490905cb3ba7511d',
#     'width': 64}],
#   'name': 'Heartbreak',
#   'release_date': '2022-02-14',
#   'release_date_precision': 'day',
#   'total_tracks': 66,
#   'type': 'album',
#   'uri': 'spotify:album:6m33bBnWHlGsIr3iyl5vJc'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0Do3fegietLfyYbVrWGNJh'},
#   'href': 'https://api.spotify.com/v1/albums/0Do3fegietLfyYbVrWGNJh',
#   'id': '0Do3fegietLfyYbVrWGNJh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27392363159e62a5171e9aff9ad',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0292363159e62a5171e9aff9ad',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485192363159e62a5171e9aff9ad',
#     'width': 64}],
#   'name': 'Romantic',
#   'release_date': '2022-02-14',
#   'release_date_precision': 'day',
#   'total_tracks': 24,
#   'type': 'album',
#   'uri': 'spotify:album:0Do3fegietLfyYbVrWGNJh'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5B1tzDsgFcD5WGFis8I47I'},
#   'href': 'https://api.spotify.com/v1/albums/5B1tzDsgFcD5WGFis8I47I',
#   'id': '5B1tzDsgFcD5WGFis8I47I',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27363e5566ee923972083f8078b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0263e5566ee923972083f8078b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485163e5566ee923972083f8078b',
#     'width': 64}],
#   'name': 'Pop Queens',
#   'release_date': '2022-02-14',
#   'release_date_precision': 'day',
#   'total_tracks': 27,
#   'type': 'album',
#   'uri': 'spotify:album:5B1tzDsgFcD5WGFis8I47I'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3tyTsXESGKY2Cob4A0x2TB'},
#   'href': 'https://api.spotify.com/v1/albums/3tyTsXESGKY2Cob4A0x2TB',
#   'id': '3tyTsXESGKY2Cob4A0x2TB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27339ddb17f168d679016a2a0bd',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0239ddb17f168d679016a2a0bd',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485139ddb17f168d679016a2a0bd',
#     'width': 64}],
#   'name': 'Valentines Day Tik Tock Hits',
#   'release_date': '2022-02-13',
#   'release_date_precision': 'day',
#   'total_tracks': 26,
#   'type': 'album',
#   'uri': 'spotify:album:3tyTsXESGKY2Cob4A0x2TB'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7jqUm13k7C1n5x4aJhl8SK'},
#   'href': 'https://api.spotify.com/v1/albums/7jqUm13k7C1n5x4aJhl8SK',
#   'id': '7jqUm13k7C1n5x4aJhl8SK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737d0f7d2e21a1f1d495481529',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027d0f7d2e21a1f1d495481529',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517d0f7d2e21a1f1d495481529',
#     'width': 64}],
#   'name': 'My Life Is A Movie',
#   'release_date': '2022-02-11',
#   'release_date_precision': 'day',
#   'total_tracks': 40,
#   'type': 'album',
#   'uri': 'spotify:album:7jqUm13k7C1n5x4aJhl8SK'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/43zDhu0ghJDVXNp6c7ysZt'},
#   'href': 'https://api.spotify.com/v1/albums/43zDhu0ghJDVXNp6c7ysZt',
#   'id': '43zDhu0ghJDVXNp6c7ysZt',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739b1eefbd0e8eb42073e8ea1a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029b1eefbd0e8eb42073e8ea1a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519b1eefbd0e8eb42073e8ea1a',
#     'width': 64}],
#   'name': 'Sad Love Songs',
#   'release_date': '2022-02-11',
#   'release_date_precision': 'day',
#   'total_tracks': 65,
#   'type': 'album',
#   'uri': 'spotify:album:43zDhu0ghJDVXNp6c7ysZt'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3nZx8DHoPX6D1UbvBv3Z8w'},
#   'href': 'https://api.spotify.com/v1/albums/3nZx8DHoPX6D1UbvBv3Z8w',
#   'id': '3nZx8DHoPX6D1UbvBv3Z8w',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27383f8c5dc9d1b2964e4c4d388',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0283f8c5dc9d1b2964e4c4d388',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485183f8c5dc9d1b2964e4c4d388',
#     'width': 64}],
#   'name': 'HEART(BREAK)',
#   'release_date': '2022-02-11',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:3nZx8DHoPX6D1UbvBv3Z8w'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1oqFL1f6NaSMO635jRSbjV'},
#   'href': 'https://api.spotify.com/v1/albums/1oqFL1f6NaSMO635jRSbjV',
#   'id': '1oqFL1f6NaSMO635jRSbjV',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331d4c93777bc01bb725fb52c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231d4c93777bc01bb725fb52c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131d4c93777bc01bb725fb52c',
#     'width': 64}],
#   'name': 'immaculate vibes',
#   'release_date': '2022-02-11',
#   'release_date_precision': 'day',
#   'total_tracks': 36,
#   'type': 'album',
#   'uri': 'spotify:album:1oqFL1f6NaSMO635jRSbjV'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1f5OzcdfEN0LrdQlajSnw9'},
#   'href': 'https://api.spotify.com/v1/albums/1f5OzcdfEN0LrdQlajSnw9',
#   'id': '1f5OzcdfEN0LrdQlajSnw9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738efc0687260e899d06e36ba5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028efc0687260e899d06e36ba5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518efc0687260e899d06e36ba5',
#     'width': 64}],
#   'name': 'Bedroom Pop 2022',
#   'release_date': '2022-02-11',
#   'release_date_precision': 'day',
#   'total_tracks': 25,
#   'type': 'album',
#   'uri': 'spotify:album:1f5OzcdfEN0LrdQlajSnw9'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3wafgtnULG0QJRzGvH51xS'},
#   'href': 'https://api.spotify.com/v1/albums/3wafgtnULG0QJRzGvH51xS',
#   'id': '3wafgtnULG0QJRzGvH51xS',
#   'images': [{'height': 640,
# ...
#   'href': 'https://api.spotify.com/v1/albums/0Aa4xsUR6VvHM9EP1hfQJm',
#   'id': '0Aa4xsUR6VvHM9EP1hfQJm',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b0522263acda39ee103a060f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b0522263acda39ee103a060f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b0522263acda39ee103a060f',
#     'width': 64}],
#   'name': 'Helix (Volume 2)',
#   'release_date': '2018-07-27',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:0Aa4xsUR6VvHM9EP1hfQJm'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2yqE49L1yCXlNYkMRZ0x5D'},
#   'href': 'https://api.spotify.com/v1/albums/2yqE49L1yCXlNYkMRZ0x5D',
#   'id': '2yqE49L1yCXlNYkMRZ0x5D',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27396b66d3535be881d630ff592',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0296b66d3535be881d630ff592',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485196b66d3535be881d630ff592',
#     'width': 64}],
#   'name': 'Break Ups To Make Ups',
#   'release_date': '2018-05-25',
#   'release_date_precision': 'day',
#   'total_tracks': 27,
#   'type': 'album',
#   'uri': 'spotify:album:2yqE49L1yCXlNYkMRZ0x5D'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#     'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#     'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#     'name': 'Selena Gomez',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#     'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#     'id': '5Pwc4xIPtQLFEnJriah9YJ',
#     'name': 'OneRepublic',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ad91Jof8Niiw0lGLLi3NW'},
#     'href': 'https://api.spotify.com/v1/artists/6Ad91Jof8Niiw0lGLLi3NW',
#     'id': '6Ad91Jof8Niiw0lGLLi3NW',
#     'name': 'YUNGBLUD',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Ad91Jof8Niiw0lGLLi3NW'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4RpgjxgSxcRwGNuWnImneN'},
#   'href': 'https://api.spotify.com/v1/albums/4RpgjxgSxcRwGNuWnImneN',
#   'id': '4RpgjxgSxcRwGNuWnImneN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273acc995be2b5bdc62d622ccd3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02acc995be2b5bdc62d622ccd3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851acc995be2b5bdc62d622ccd3',
#     'width': 64}],
#   'name': '13 Reasons Why (Season 2)',
#   'release_date': '2018-05-18',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:4RpgjxgSxcRwGNuWnImneN'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4Vf5l1TvPROSWTSzIj9v6i'},
#   'href': 'https://api.spotify.com/v1/albums/4Vf5l1TvPROSWTSzIj9v6i',
#   'id': '4Vf5l1TvPROSWTSzIj9v6i',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ac2372b9d344a5d3fc9167cc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ac2372b9d344a5d3fc9167cc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ac2372b9d344a5d3fc9167cc',
#     'width': 64}],
#   'name': 'Top 30 US',
#   'release_date': '2018-04-27',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:4Vf5l1TvPROSWTSzIj9v6i'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/41vkdnhery9pTR4iBwpeKn'},
#   'href': 'https://api.spotify.com/v1/albums/41vkdnhery9pTR4iBwpeKn',
#   'id': '41vkdnhery9pTR4iBwpeKn',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733f0479a898ea907cf54d8064',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023f0479a898ea907cf54d8064',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513f0479a898ea907cf54d8064',
#     'width': 64}],
#   'name': 'Chill Wind Down',
#   'release_date': '2018-04-20',
#   'release_date_precision': 'day',
#   'total_tracks': 28,
#   'type': 'album',
#   'uri': 'spotify:album:41vkdnhery9pTR4iBwpeKn'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0UURABllcIvOWRXAyzMQsy'},
#   'href': 'https://api.spotify.com/v1/albums/0UURABllcIvOWRXAyzMQsy',
#   'id': '0UURABllcIvOWRXAyzMQsy',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331c25321f3ac749834c99c46',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231c25321f3ac749834c99c46',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131c25321f3ac749834c99c46',
#     'width': 64}],
#   'name': 'Fresh For 2018',
#   'release_date': '2018-01-19',
#   'release_date_precision': 'day',
#   'total_tracks': 43,
#   'type': 'album',
#   'uri': 'spotify:album:0UURABllcIvOWRXAyzMQsy'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5bL1zO5hy4pwIActiffZSo'},
#   'href': 'https://api.spotify.com/v1/albums/5bL1zO5hy4pwIActiffZSo',
#   'id': '5bL1zO5hy4pwIActiffZSo',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730cde228fbe420a543938a929',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020cde228fbe420a543938a929',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510cde228fbe420a543938a929',
#     'width': 64}],
#   'name': 'Helix (Volume 1)',
#   'release_date': '2017-11-17',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:5bL1zO5hy4pwIActiffZSo'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0qMJpB1ZbVLU0p0RkrNyQN'},
#   'href': 'https://api.spotify.com/v1/albums/0qMJpB1ZbVLU0p0RkrNyQN',
#   'id': '0qMJpB1ZbVLU0p0RkrNyQN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273191d9212a062cb992a535735',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02191d9212a062cb992a535735',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851191d9212a062cb992a535735',
#     'width': 64}],
#   'name': 'Pastel Goth',
#   'release_date': '2017-09-22',
#   'release_date_precision': 'day',
#   'total_tracks': 22,
#   'type': 'album',
#   'uri': 'spotify:album:0qMJpB1ZbVLU0p0RkrNyQN'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5L5J1xNm6oQb6AZtQYsctQ'},
#   'href': 'https://api.spotify.com/v1/albums/5L5J1xNm6oQb6AZtQYsctQ',
#   'id': '5L5J1xNm6oQb6AZtQYsctQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273118fab08371fc6510323d739',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02118fab08371fc6510323d739',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851118fab08371fc6510323d739',
#     'width': 64}],
#   'name': 'Deep Songwriters',
#   'release_date': '2017-09-01',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:5L5J1xNm6oQb6AZtQYsctQ'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/35zjbqKjGdbXOIrpmo9ZGS'},
#   'href': 'https://api.spotify.com/v1/albums/35zjbqKjGdbXOIrpmo9ZGS',
#   'id': '35zjbqKjGdbXOIrpmo9ZGS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27338a23f2044ab928d803021f8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0238a23f2044ab928d803021f8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485138a23f2044ab928d803021f8',
#     'width': 64}],
#   'name': 'Electronic Chill',
#   'release_date': '2017-08-18',
#   'release_date_precision': 'day',
#   'total_tracks': 23,
#   'type': 'album',
#   'uri': 'spotify:album:35zjbqKjGdbXOIrpmo9ZGS'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/03zG7RXfRVtembbdsQaop1'},
#   'href': 'https://api.spotify.com/v1/albums/03zG7RXfRVtembbdsQaop1',
#   'id': '03zG7RXfRVtembbdsQaop1',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27392eb52c21aa666d0b1e1370d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0292eb52c21aa666d0b1e1370d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485192eb52c21aa666d0b1e1370d',
#     'width': 64}],
#   'name': 'Background Music',
#   'release_date': '2017-08-04',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:03zG7RXfRVtembbdsQaop1'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0vCnfRymNflFa4Zx9mZCwZ'},
#   'href': 'https://api.spotify.com/v1/albums/0vCnfRymNflFa4Zx9mZCwZ',
#   'id': '0vCnfRymNflFa4Zx9mZCwZ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b65ed1440e4f16f4d62669d0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b65ed1440e4f16f4d62669d0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b65ed1440e4f16f4d62669d0',
#     'width': 64}],
#   'name': 'Everything, Everything (Original Motion Picture Soundtrack)',
#   'release_date': '2017-05-17',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:0vCnfRymNflFa4Zx9mZCwZ'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2OicPkzxga0ybQIdl3kvaa'},
#   'href': 'https://api.spotify.com/v1/albums/2OicPkzxga0ybQIdl3kvaa',
#   'id': '2OicPkzxga0ybQIdl3kvaa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738e0cf26ddc14f90080a62aac',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028e0cf26ddc14f90080a62aac',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518e0cf26ddc14f90080a62aac',
#     'width': 64}],
#   'name': '13 Reasons Why (A Netflix Original Series Soundtrack)',
#   'release_date': '2017-03-30',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:2OicPkzxga0ybQIdl3kvaa'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7z3lbsoJ6fqaYdPWaOYnB2'},
#   'href': 'https://api.spotify.com/v1/albums/7z3lbsoJ6fqaYdPWaOYnB2',
#   'id': '7z3lbsoJ6fqaYdPWaOYnB2',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f39cf592977ea48323d58638',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f39cf592977ea48323d58638',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f39cf592977ea48323d58638',
#     'width': 64}],
#   'name': 'Common Culture, Vol. V by Connor Franta',
#   'release_date': '2016-04-29',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:7z3lbsoJ6fqaYdPWaOYnB2'}]

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

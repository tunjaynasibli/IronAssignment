# %%
import pandas as pd

# %%
data1 = pd.read_csv("file1.csv")
data2 = pd.read_csv("file2.csv")
data3 = pd.read_csv("file3.csv")
print(data1.columns)
print(data2.columns)
print(data3.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
def standardize(df):
    columns_lower = []

    for column in df.columns:
        columns_lower.append(column.lower().replace(" ", "_"))
    df.columns = columns_lower 

    return df

# %%
standardize(data1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
standardize(data2)
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
standardize(data3)
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
data1.drop("customer", axis=1, inplace=True)
data2.drop("customer", axis=1, inplace=True)
data3.drop("customer", axis=1, inplace=True)

# %%
data2 = data2.reindex(columns=["st", "gender", "education", 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount'])

# %%
data3 = data3.reindex(columns=["st", "gender", "education", 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount'])

# %%
data_result = pd.concat([data1, data2, data3])

# %%
data_result
# Out:
#               st gender             education customer_lifetime_value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065         NaN      M              Bachelor             23405.98798
# 7066         NaN      F               College             3096.511217
# 7067         NaN      M              Bachelor             8163.890428
# 7068         NaN      M               College             7524.442436
# 7069         NaN      M               College             2611.836866
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
data_result.dtypes
# Out:
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
data_result["customer_lifetime_value"] = data_result["customer_lifetime_value"].astype(str).str.replace("%", "")

# %%
data_result["customer_lifetime_value"] = data_result["customer_lifetime_value"].astype(float)
data_result["customer_lifetime_value"] = round(data_result["customer_lifetime_value"], 1)

# %%
data_result
# Out:
#               st gender             education  customer_lifetime_value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                 697953.6
# 2         Nevada      F              Bachelor                1288743.2
# 3     California      M              Bachelor                 764586.2
# 4     Washington      M  High School or Below                 536307.6
# ...          ...    ...                   ...                      ...
# 7065         NaN      M              Bachelor                  23406.0
# 7066         NaN      F               College                   3096.5
# 7067         NaN      M              Bachelor                   8163.9
# 7068         NaN      M               College                   7524.4
# 7069         NaN      M               College                   2611.8
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
data_result.dropna(how="all")
# Out:
#               st gender             education  customer_lifetime_value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                 697953.6
# 2         Nevada      F              Bachelor                1288743.2
# 3     California      M              Bachelor                 764586.2
# 4     Washington      M  High School or Below                 536307.6
# ...          ...    ...                   ...                      ...
# 7065         NaN      M              Bachelor                  23406.0
# 7066         NaN      F               College                   3096.5
# 7067         NaN      M              Bachelor                   8163.9
# 7068         NaN      M               College                   7524.4
# 7069         NaN      M               College                   2611.8
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
data_result["st"].value_counts()
# Out:
# Oregon        623
# California    488
# Arizona       328
# Nevada        223
# Washington    181
# Cali          120
# AZ             74
# WA             30
# Name: st, dtype: int64

# %%
data_result["st"] = data_result["st"].replace("WA", "Washington")
data_result["st"] = data_result["st"].replace("Cali", "California")
data_result["st"] = data_result["st"].replace("AZ", "Arizona")

# %%
data_result["st"].value_counts()
# Out:
# Oregon        623
# California    608
# Arizona       402
# Nevada        223
# Washington    211
# Name: st, dtype: int64

# %%
data_result["gender"].value_counts()
# Out:
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %%
data_result["gender"] = data_result["gender"].replace("Male", "M")
data_result["gender"] = data_result["gender"].replace("female", "F")
data_result["gender"] = data_result["gender"].replace("Femal", "F")

# %%
data_result["gender"].value_counts()
# Out:
# F    4607
# M    4408
# Name: gender, dtype: int64

# %%
data_result = data_result.drop_duplicates()

# %%
data_result
# Out:
#               st gender             education  customer_lifetime_value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                 697953.6
# 2         Nevada      F              Bachelor                1288743.2
# 3     California      M              Bachelor                 764586.2
# 4     Washington      M  High School or Below                 536307.6
# ...          ...    ...                   ...                      ...
# 7064         NaN      F               College                   4100.4
# 7065         NaN      M              Bachelor                  23406.0
# 7067         NaN      M              Bachelor                   8163.9
# 7068         NaN      M               College                   7524.4
# 7069         NaN      M               College                   2611.8
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
data_result["total_claim_amount"] = round(data_result["total_claim_amount"], 1)
# Out:
# /var/folders/xw/scy5flt94d56tjrc4x62mjrc0000gn/T/ipykernel_18544/3429266680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result["total_claim_amount"] = round(data_result["total_claim_amount"], 1)

# %%
data_result
# Out:
#               st gender             education  customer_lifetime_value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                 697953.6
# 2         Nevada      F              Bachelor                1288743.2
# 3     California      M              Bachelor                 764586.2
# 4     Washington      M  High School or Below                 536307.6
# ...          ...    ...                   ...                      ...
# 7064         NaN      F               College                   4100.4
# 7065         NaN      M              Bachelor                  23406.0
# 7067         NaN      M              Bachelor                   8163.9
# 7068         NaN      M               College                   7524.4
# 7069         NaN      M               College                   2611.8
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
data_result.dtypes
# Out:
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
data_result["number_of_open_complaints"].value_counts()
# Out:
# 0         5137
# 1/0/00    1613
# 1          711
# 2          271
# 1/1/00     244
# 3          203
# 4          107
# 1/2/00      93
# 1/3/00      58
# 5           41
# 1/4/00      28
# 1/5/00      12
# Name: number_of_open_complaints, dtype: int64

# %%
data_result.replace({"number_of_open_complaints" : {"1/0/00" : 0, "1/1/00" : 1, "1/2/00" : 2, "1/3/00" : 3, "1/4/00" : 4, "1/5/00" : 5}}, inplace=True)
# Out:
# /Users/tuncaynasibli/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
data_result["number_of_open_complaints"].value_counts()
# Out:
# 0.0    6750
# 1.0     955
# 2.0     364
# 3.0     261
# 4.0     135
# 5.0      53
# Name: number_of_open_complaints, dtype: int64

# %%
data_result.isna().sum()
# Out:
# st                           6471
# gender                        123
# education                       1
# customer_lifetime_value         8
# income                          1
# monthly_premium_auto            1
# number_of_open_complaints       1
# policy_type                     1
# vehicle_class                   1
# total_claim_amount              1
# dtype: int64

# %%
data_result[data_result["st"].isna()]
# Out:
#        st gender             education  customer_lifetime_value   income  \
# 1071  NaN    NaN                   NaN                      NaN      NaN
# 0     NaN      M  High School or Below                   3479.1      0.0
# 1     NaN      M                Master                   2502.6      0.0
# 2     NaN      F              Bachelor                   3265.2  25820.0
# 3     NaN      F  High School or Below                   4455.8      0.0
# ...   ...    ...                   ...                      ...      ...
# 7064  NaN      F               College                   4100.4  47761.0
# 7065  NaN      M              Bachelor                  23406.0  71941.0
# 7067  NaN      M              Bachelor                   8163.9      0.0
# 7068  NaN      M               College                   7524.4  21941.0
# 7069  NaN      M               College                   2611.8      0.0
#
#       monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
data_result["st"].fillna("Not given", inplace=True)
# Out:
# /Users/tuncaynasibli/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_result.isna().sum()
# Out:
# st                             0
# gender                       123
# education                      1
# customer_lifetime_value        8
# income                         1
# monthly_premium_auto           1
# number_of_open_complaints      1
# policy_type                    1
# vehicle_class                  1
# total_claim_amount             1
# dtype: int64

# %%
data_result[data_result["gender"].isna()]
# Out:
#              st gender             education  customer_lifetime_value  \
# 0    Washington    NaN                Master                      NaN
# 11   California    NaN               College                 819719.7
# 12   California    NaN                Master                 879879.7
# 13      Arizona    NaN  High School or Below                 881901.9
# 14   California    NaN               College                 538443.2
# ..          ...    ...                   ...                      ...
# 167  Washington    NaN               College                 244366.5
# 228  Washington    NaN              Bachelor                 501888.5
# 257  Washington    NaN              Bachelor                 485474.6
# 372  Washington    NaN  High School or Below                      NaN
# 980  Washington    NaN              Bachelor                 304179.2
#
#       income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
data_result["gender"].fillna("Not given", inplace=True)
# Out:
# /Users/tuncaynasibli/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_result[data_result["education"].isna()]
# Out:
#              st     gender education  customer_lifetime_value  income  \
# 1071  Not given  Not given       NaN                      NaN     NaN
#
#       monthly_premium_auto  number_of_open_complaints policy_type  \
# 1071                   NaN                        NaN         NaN
#
#      vehicle_class  total_claim_amount
# 1071           NaN                 NaN

# %%
data_result.dropna(thresh=4)
# Out:
#               st     gender             education  customer_lifetime_value  \
# 0     Washington  Not given                Master                      NaN
# 1        Arizona          F              Bachelor                 697953.6
# 2         Nevada          F              Bachelor                1288743.2
# 3     California          M              Bachelor                 764586.2
# 4     Washington          M  High School or Below                 536307.6
# ...          ...        ...                   ...                      ...
# 7064   Not given          F               College                   4100.4
# 7065   Not given          M              Bachelor                  23406.0
# 7067   Not given          M              Bachelor                   8163.9
# 7068   Not given          M               College                   7524.4
# 7069   Not given          M               College                   2611.8
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
data_result.isna().sum()
# Out:
# st                           0
# gender                       0
# education                    1
# customer_lifetime_value      8
# income                       1
# monthly_premium_auto         1
# number_of_open_complaints    1
# policy_type                  1
# vehicle_class                1
# total_claim_amount           1
# dtype: int64

# %%
data_result[data_result["customer_lifetime_value"].isna()]
# Out:
#               st     gender             education  customer_lifetime_value  \
# 0     Washington  Not given                Master                      NaN
# 78    Washington          F                Master                      NaN
# 988   Washington          M  High School or Below                      NaN
# 1071   Not given  Not given                   NaN                      NaN
# 325   Washington          M  High School or Below                      NaN
# 372   Washington  Not given  High School or Below                      NaN
# 580   Washington          M                Master                      NaN
# 861   Washington          F             Bachelors                      NaN
#
#        income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0         0.0                1000.0                        0.0  Personal Auto
# 78    41275.0                  96.0                        0.0  Personal Auto
# ...

# %%
data_result = data_result[data_result["customer_lifetime_value"].notna()]

# %%
data_result[data_result["customer_lifetime_value"].isna()]
# Out:
# Empty DataFrame
# Columns: [st, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, policy_type, vehicle_class, total_claim_amount]
# Index: []

# %%
data_result
# Out:
#               st gender             education  customer_lifetime_value  \
# 1        Arizona      F              Bachelor                 697953.6
# 2         Nevada      F              Bachelor                1288743.2
# 3     California      M              Bachelor                 764586.2
# 4     Washington      M  High School or Below                 536307.6
# 5         Oregon      F              Bachelor                 825629.8
# ...          ...    ...                   ...                      ...
# 7064   Not given      F               College                   4100.4
# 7065   Not given      M              Bachelor                  23406.0
# 7067   Not given      M              Bachelor                   8163.9
# 7068   Not given      M               College                   7524.4
# 7069   Not given      M               College                   2611.8
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
data_result.isna().sum()
# Out:
# st                           0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
data_result.replace({"st" : {"California" : "West Region", "Oregon" : "North West", "Washington" : "East", "Arizona" : "Central", "Nevada" : "Central" }}, inplace=True)
##California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

# %%
data_result
# Out:
#                st gender             education  customer_lifetime_value  \
# 1         Central      F              Bachelor                 697953.6
# 2         Central      F              Bachelor                1288743.2
# 3     West Region      M              Bachelor                 764586.2
# 4            East      M  High School or Below                 536307.6
# 5      North West      F              Bachelor                 825629.8
# ...           ...    ...                   ...                      ...
# 7064    Not given      F               College                   4100.4
# 7065    Not given      M              Bachelor                  23406.0
# 7067    Not given      M              Bachelor                   8163.9
# 7068    Not given      M               College                   7524.4
# 7069    Not given      M               College                   2611.8
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...
